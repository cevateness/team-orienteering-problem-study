# %%
import random
import math
import copy
from collections import deque, defaultdict
import gurobipy as gp
from gurobipy import GRB

# %%
def read_top_instance(file_path):
    with open(file_path, 'r') as file:
        # Read the first three lines
        n_line = file.readline().strip()
        m_line = file.readline().strip()
        tmax_line = file.readline().strip()

        # Parse n N
        _, N = n_line.split()
        N = int(N)

        # Parse m P
        _, P = m_line.split()
        P = int(P)

        # Parse tmax Tmax
        _, Tmax = tmax_line.split()
        Tmax = float(Tmax)

        # Read the remaining lines for each node
        nodes = []
        for i in range(N):
            line = file.readline().strip()
            if line == '':
                continue  # Skip empty lines
            x_str, y_str, s_str = line.split()
            x = float(x_str)
            y = float(y_str)
            s = float(s_str)
            nodes.append({'id': i, 'x': x, 'y': y, 'score': s})

        return N, P, Tmax, nodes

# %%
# define problem instance. 
class ProblemInstance:
    def __init__(self, file_path):
        """
        Initialize the problem instance by reading data from a file.

        :param file_path: Path to the instance data file
        """
        self.N, self.P, self.Tmax, self.nodes = read_top_instance(file_path)
        self.distance_matrix = self.compute_distance_matrix()
        self.original_start_id = 0
        self.original_end_id = self.N - 1

    def compute_distance_matrix(self):
        """
        Compute the Euclidean distance matrix keyed by node IDs.

        :return: A dictionary of dictionaries representing the distance matrix, 
                where distance_matrix[id1][id2] = distance between node id1 and id2.
        """
        # Initialize the distance matrix as a nested dictionary
        distance_matrix = {}
        
        # Extract all node IDs and coordinates for convenience
        nodes_info = {node['id']: (node['x'], node['y']) for node in self.nodes}

        for id1, (x1, y1) in nodes_info.items():
            distance_matrix[id1] = {}
            for id2, (x2, y2) in nodes_info.items():
                if id1 == id2:
                    distance_matrix[id1][id2] = 0.0
                else:
                    distance = math.hypot(x1 - x2, y1 - y2)
                    distance_matrix[id1][id2] = distance

        return distance_matrix

# %%
import logging


class HALNS:
    def __init__(self, file_path, parameters):
        """
        Initialize the HALNS heuristic with the given problem instance file and parameters.

        :param file_path: Path to the TOP instance data file
        :param parameters: A dictionary containing algorithm parameters
        """
        self.problem = ProblemInstance(file_path)
        self.params = parameters

        # Initialize variables
        self.s_best = None
        self.s_adm = None
        self.T = self.params['T0']
        self.seg = 0
        self.iteration_best = 0
        self.s_best = None
        self.s_adm = None
        self.routes_list = []  # List of tuples: (route, profit, coverage)
        self.generated_routes = set()  # Set of frozensets representing unique routes


        # Initialize scores for strategies and operators
        # Mapped from the paper: dynamic profit/time, highest profit, random, LRFI
        self.selection_strategies = [
            'dynamic_profit_per_time', 
            'highest_profit',
            'random',
            'lrfi'
        ]

        self.removal_ops = [
            'random_removal',
            'lowest_profit_removal',
            'largest_saving_removal',
            'route_removal',
            'sequence_removal'
        ]
        
        self.insertion_ops = [
            'first_available',
            'last_available',
            'random_available',
            'best_overall_position',
            'best_position'
        ]

        self.selection_scores = {}
        self.selection_observed_scores = {}
        self.selection_counts = {}

        self.removal_scores = {}
        self.removal_observed_scores = {}
        self.removal_counts = {}

        self.insertion_scores = {}
        self.insertion_observed_scores = {}
        self.insertion_counts = {}

        # Keep track of last removed nodes for LRFI strategy
        self.last_removed_nodes = deque(maxlen=self.params.get('lrfi_count', 10))



    def _compute_route_time(self, route):
        dm = self.problem.distance_matrix
        time = 0.0
        for i in range(len(route)-1):
            time += dm[route[i]][route[i+1]]
        return time

    def _compute_solution_travel_time(self, solution):
        return sum(self._compute_route_time(r) for r in solution)

    def _is_feasible_insertion(self, route, pos, node):
        # Check feasibility of inserting node at route[pos]
        # For simplicity, assume feasibility = route time <= Tmax after insertion
        dm = self.problem.distance_matrix
        new_route = route[:pos] + [node] + route[pos:]
        return self._compute_route_time(new_route) <= self.problem.Tmax

    def _insert_node_in_position(self, route, pos, node):
        route.insert(pos, node)

    def _incremental_time_for_insertion(self, route, pos, node):
        dm = self.problem.distance_matrix
        before = dm[route[pos-1]][route[pos]]
        after = dm[route[pos-1]][node] + dm[node][route[pos]]
        return after - before
    

    def detect_subtours(self, x_sol, V, A, start_node, end_node):
        """
        Detect subtours in the current solution using Tarjan's algorithm.
        
        :param x_sol: Dictionary with keys as (i,j) tuples and values as x[i,j].
        :param V: Set of all nodes.
        :param A: Set of all arcs.
        :param start_node: Start depot node ID.
        :param end_node: End depot node ID.
        :return: List of sets, each representing a subtour.
        """
        graph = defaultdict(list)
        for (i, j), val in x_sol.items():
            if val > 0.9:
                graph[i].append(j)

        # Tarjan's algorithm for SCCs
        index = {}
        lowlink = {}
        stack = []
        onstack = set()
        sccs = []
        current_index = 0

        def strongconnect(v):
            nonlocal current_index
            index[v] = current_index
            lowlink[v] = current_index
            current_index += 1
            stack.append(v)
            onstack.add(v)

            for w in graph[v]:
                if w not in index:
                    strongconnect(w)
                    lowlink[v] = min(lowlink[v], lowlink[w])
                elif w in onstack:
                    lowlink[v] = min(lowlink[v], index[w])

            # If v is a root node, pop the stack and generate an SCC
            if lowlink[v] == index[v]:
                scc = set()
                while True:
                    w = stack.pop()
                    onstack.remove(w)
                    scc.add(w)
                    if w == v:
                        break
                # **Remove the exclusion of start_node and end_node**
                if len(scc) > 1:
                    sccs.append(scc)

        for v in V:
            if v not in index:
                strongconnect(v)

        return sccs


    def srop_subtour_callback(self, model, where):
        """
        Callback function to eliminate subtours in the SROP model.
        
        :param model: The Gurobi model.
        :param where: The callback context.
        """
        if where == GRB.Callback.MIPSOL:
            x = model._x
            V = model._V
            A = model._A
            o = model._start_node
            d = model._end_node

            # Retrieve the current solution
            x_sol = {}
            for (i, j) in A:
                val = model.cbGetSolution(x[i, j])
                x_sol[(i, j)] = val

            # Detect subtours
            subtours = self.detect_subtours(x_sol, V, A, o, d)

            # Add lazy constraints to eliminate each subtour found
            for S in subtours:
                lhs = gp.LinExpr()
                for i in S:
                    for j in S:
                        if (i, j) in A and i != j:
                            lhs.add(x[i, j], 1)
                model.cbLazy(lhs <= len(S) - 1)
                logging.info(f"Added subtour elimination constraint for subset: {S}")




    def node_elimination_procedure(self):
        """
        Apply a node elimination procedure.
        This procedure removes nodes that cannot be serviced within the allowed time budget.
        A node i is eliminated if even the direct route s -> i -> e exceeds Tmax.
        """
        logging.info("Applying node elimination procedure...")

        # Extract relevant information from the problem instance
        N = self.problem.N
        distance_matrix = self.problem.distance_matrix
        Tmax = self.problem.Tmax

        start_node = 0
        end_node = N - 1

        # Mandatory nodes (start and end) cannot be eliminated
        # We'll create a new list of nodes that remain feasible after elimination
        feasible_nodes = []

        # For each node, check feasibility:
        for node in self.problem.nodes:
            i = node['id']
            
            # Skip start and end nodes as they must remain
            if i == start_node or i == end_node:
                feasible_nodes.append(node)
                continue

            # Compute minimal route time s -> i -> e
            T_sie = distance_matrix[start_node][i] + distance_matrix[i][end_node]

            if T_sie <= Tmax:
                # This node could potentially be serviced in some feasible route
                feasible_nodes.append(node)
            else:
                # Node cannot be serviced within Tmax, so it is eliminated
                logging.info(f"Eliminating node {i} due to infeasibility (s->i->e exceeds Tmax).")

        # Update the problem instance with the reduced set of nodes
        self.problem.nodes = feasible_nodes
        # Update N to reflect the new number of nodes
        self.problem.N = len(feasible_nodes)

        # Create a dictionary keyed by node id for direct access:
        self.problem.node_dict = {node['id']: node for node in self.problem.nodes}

        logging.info("Node elimination procedure completed.")
    
    def construct_initial_solution(self):
        logging.info("Constructing initial solution using the nearest neighbor algorithm...")

        start_node = self.problem.original_start_id
        end_node = self.problem.original_end_id

        unvisited = {nid for nid in self.problem.node_dict.keys() if nid not in {start_node, end_node}}
        paths = [[start_node, end_node] for _ in range(self.problem.P)]
        current_times = []
        for p in range(self.problem.P):
            initial_time = self.problem.distance_matrix[start_node][end_node]
            current_times.append(initial_time)

        current_positions = [start_node for _ in range(self.problem.P)]

        while unvisited:
            improvement = False
            for p in range(self.problem.P):
                last_node = current_positions[p]
                best_node = None
                best_score = -1
                best_distance = float('inf')

                for node_id in unvisited:
                    distance = self.problem.distance_matrix[last_node][node_id]
                    distance_to_end = self.problem.distance_matrix[node_id][end_node]
                    new_total_time = current_times[p] - self.problem.distance_matrix[last_node][end_node] + distance + distance_to_end

                    if new_total_time <= self.problem.Tmax:
                        node_score = self.problem.node_dict[node_id]['score']  
                        heuristic = node_score / (distance + 1)
                        if heuristic > best_score:
                            best_score = heuristic
                            best_node = node_id
                            best_distance = distance

                if best_node is not None:
                    paths[p].insert(-1, best_node)
                    unvisited.remove(best_node)
                    current_times[p] = current_times[p] - self.problem.distance_matrix[last_node][end_node] + best_distance + self.problem.distance_matrix[best_node][end_node]
                    current_positions[p] = best_node
                    improvement = True
                    logging.info(f"Path {p + 1}: Added node {best_node} (Score: {self.problem.node_dict[best_node]['score']}, Distance: {best_distance:.2f})")

            if not improvement:
                logging.info("No further nodes can be added without exceeding Tmax.")
                break

        for p in range(self.problem.P):
            if paths[p][-1] != end_node:
                paths[p].append(end_node)
                logging.info(f"Path {p + 1}: Ensured ending at node {end_node}. Total time: {current_times[p]:.2f}")
                self.add_route_if_unique(p)

        self.s_best = paths
        self.s_adm = copy.deepcopy(paths)
        logging.info("Initial solution constructed with time budget consideration.")
        return paths
        
    def initialize_scores(self):
        """
        Initialize the scores of the node selection strategy and the removal and insertion operators.
        """
        logging.info("Initializing scores for strategies and operators...")

        # Each strategy/operator starts with a score of 1.0 as per the described approach
        for strat in self.selection_strategies:
            self.selection_scores[strat] = 1.0
            self.selection_observed_scores[strat] = 0.0
            self.selection_counts[strat] = 0

        for rem in self.removal_ops:
            self.removal_scores[rem] = 1.0
            self.removal_observed_scores[rem] = 0.0
            self.removal_counts[rem] = 0

        for ins in self.insertion_ops:
            self.insertion_scores[ins] = 1.0
            self.insertion_observed_scores[ins] = 0.0
            self.insertion_counts[ins] = 0
    
    def select_node_selection_strategy(self):
        """
        Select a node selection strategy based on current scores.
        A roulette wheel selection is performed:
        P_k = p_k / sum_of_all_p
        The strategies are:
        1. dynamic_profit_per_time
        2. highest_profit
        3. random
        4. lrfi
        """
        logging.info("Selecting node selection strategy...")
        total_score = sum(self.selection_scores.values())
        r = random.uniform(0, total_score)
        cumulative = 0.0
        for strat, score in self.selection_scores.items():
            cumulative += score
            if r <= cumulative:
                return strat
        # Fallback in case of numerical issues
        return self.selection_strategies[0]
    
    def select_removal_insertion_operators(self):
        """
        Select removal and insertion operators based on current scores via roulette wheel selection.
        """
        logging.info("Selecting removal and insertion operators...")

        # Removal operator selection
        total_score_rem = sum(self.removal_scores.values())
        r_rem = random.uniform(0, total_score_rem)
        cumulative_rem = 0.0
        selected_removal = None
        for rem, score in self.removal_scores.items():
            cumulative_rem += score
            if r_rem <= cumulative_rem:
                selected_removal = rem
                break

        # Insertion operator selection
        total_score_ins = sum(self.insertion_scores.values())
        r_ins = random.uniform(0, total_score_ins)
        cumulative_ins = 0.0
        selected_insertion = None
        for ins, score in self.insertion_scores.items():
            cumulative_ins += score
            if r_ins <= cumulative_ins:
                selected_insertion = ins
                break

        return selected_removal, selected_insertion
    
    def remove_nodes(self, solution, b, removal_operator,ratio_sequence_to_remove):
            logging.info(f"Removing nodes using {removal_operator}...")
            
            if removal_operator == 'random_removal':
                removed = self._remove_random_nodes(solution, b)
            elif removal_operator == 'lowest_profit_removal':
                removed = self._remove_lowest_profit_nodes(solution, b)
            elif removal_operator == 'largest_saving_removal':
                removed = self._remove_largest_saving_nodes(solution, b)
            elif removal_operator == 'route_removal':
                removed = self._remove_route(solution)
            elif removal_operator == 'sequence_removal':
                removed = self._remove_sequence(solution, ratio_sequence_to_remove)
            else:
                # Default to random removal if unknown
                removed = self._remove_random_nodes(solution, b)
            
            # Update solution by removing chosen nodes
            for route in solution:
                route[:] = [x for x in route if x not in removed]

            # Update LRFI queue
            for n in removed:
                self.last_removed_nodes.appendleft(n)
            
            return solution

    def _remove_random_nodes(self, solution, b):
        nodes = [n for route in solution for n in route if n not in (self.problem.original_start_id, self.problem.original_end_id)]
        removed = set()
        for _ in range(min(b, len(nodes))):
            n = random.choice(nodes)
            nodes.remove(n)
            removed.add(n)
        return removed

    def _remove_lowest_profit_nodes(self, solution, b):
        # Weighted removal based on lowest profit: nodes with lower profit are more likely to be chosen
        nodes = [n for route in solution for n in route if n not in (self.problem.original_start_id, self.problem.original_end_id)]
        if not nodes:
            return set()
        
        # Sort by profit ascending
        nodes.sort(key=lambda x: self.problem.node_dict[x]['score'])
        total_profit = sum(self.problem.node_dict[n]['score'] for n in nodes) + 1e-9
        removed = set()
        for _ in range(min(b, len(nodes))):
            # Roulette wheel giving higher chance to lower profit nodes
            r = random.uniform(0, total_profit)
            cumulative = 0.0
            chosen = nodes[0]
            for n in nodes:
                cumulative += self.problem.node_dict[n]['score']
                if r <= cumulative:
                    chosen = n
                    break
            removed.add(chosen)
            nodes.remove(chosen)
            total_profit -= self.problem.node_dict[chosen]['score']
        return removed

    def _remove_largest_saving_nodes(self, solution, b):
        # Compute saving in travel time for removing each node: D(s) - D(s\i)
        # First compute D(s)
        original_time = self._compute_solution_travel_time(solution)

        # For each node, compute saving
        candidates = []
        for r_idx, route in enumerate(solution):
            for i in range(1, len(route)-1):
                n = route[i]
                # Temporarily remove node n and compute new time
                temp_route = route[:i] + route[i+1:]
                temp_sol = solution[:r_idx] + [temp_route] + solution[r_idx+1:]
                new_time = self._compute_solution_travel_time(temp_sol)
                saving = original_time - new_time
                candidates.append((n, saving))
        
        if not candidates:
            return set()

        # Sort by saving descending, then use roulette wheel with weights = saving
        total_saving = sum(s for _, s in candidates) + 1e-9
        removed = set()
        nodes_list = candidates[:]
        # Remove b nodes with preference to largest saving
        for _ in range(min(b, len(nodes_list))):
            r = random.uniform(0, total_saving)
            cumulative = 0.0
            chosen = nodes_list[0][0]
            for (nd, sv) in nodes_list:
                cumulative += sv
                if r <= cumulative:
                    chosen = nd
                    break
            removed.add(chosen)
            # Remove chosen from candidate list and adjust total_saving
            for idx, (nd, sv) in enumerate(nodes_list):
                if nd == chosen:
                    total_saving -= sv
                    del nodes_list[idx]
                    break
        return removed

    def _remove_route(self, solution):
        # Randomly select a route (other than maybe a trivial one) and remove all nodes from it
        non_empty_routes = [r for r in solution if len(r) > 2]
        if not non_empty_routes:
            # If no non-empty routes, nothing to remove
            return set()
        route = random.choice(non_empty_routes)
        # Remove all non-depot nodes
        removed = set(route[1:-1])
        return removed

    def _remove_sequence(self, solution, ratio_sequence_to_remove):
        route = random.choice(solution)
        start_idx = random.randint(2, 2 + int(ratio_sequence_to_remove*len(route)) )
        removed = set(route[start_idx:start_idx+ int(ratio_sequence_to_remove*len(route))])
        return removed

    # insertion operators
    def insert_nodes(self, solution, insertion_operator, strategy):
        logging.info(f"Inserting nodes using {insertion_operator} with strategy {strategy}...")
        
        # Determine nodes to insert based on strategy (already chosen and ordered)
        visited = {nid for r in solution for nid in r}
        start_node = self.problem.original_start_id
        end_node =  self.problem.original_end_id
        unvisited = set(self.problem.node_dict.keys()) - visited - {start_node, end_node}

        # Strategy decides the order in which nodes are considered. This is handled separately.
        # Here we assume the `strategy` has already selected insertion_order in a previous step.
        # For demonstration, let's assume we have the insertion_order from node selection strategy step:
        # In real code, you'd integrate your node selection strategy logic here.
        insertion_order = self._get_insertion_order(unvisited, strategy)

        # Apply the chosen insertion operator to insert nodes in the given order
        if insertion_operator == 'first_available':
            solution = self._insert_nodes_first_available(solution, insertion_order)
        elif insertion_operator == 'last_available':
            solution = self._insert_nodes_last_available(solution, insertion_order)
        elif insertion_operator == 'random_available':
            solution = self._insert_nodes_random_available(solution, insertion_order)
        elif insertion_operator == 'best_overall_position':
            solution = self._insert_nodes_best_overall_position(solution, insertion_order)
        elif insertion_operator == 'best_position':
            solution = self._insert_nodes_best_position(solution, insertion_order)
        else:
            # Default to a simple operator, e.g., first_available
            solution = self._insert_nodes_first_available(solution, insertion_order)
        
        return solution

    def _get_insertion_order(self, unvisited, strategy):
        """
        Determine the order in which nodes from 'unvisited' should be considered for insertion
        based on the selected node selection strategy.
        Strategies:
        - dynamic_profit_per_time
        - highest_profit
        - random
        - lrfi
        """
        if not unvisited:
            return []

        if strategy == 'dynamic_profit_per_time':
            # Compute p_i / D(s+i) for each node i
            candidates = []
            for n in unvisited:
                profit = self.problem.node_dict[n]['score']
                incremental_time = self._compute_min_incremental_time(self.s_adm, n)
                ratio = profit / incremental_time if incremental_time > 0 else float('inf')
                candidates.append((n, ratio))
            # Sort by ratio descending
            candidates.sort(key=lambda x: x[1], reverse=True)
            insertion_list = [n for n, _ in candidates]

        elif strategy == 'highest_profit':
            # Roulette wheel based on profit
            temp_nodes = list(unvisited)
            insertion_list = []
            total_profit = sum(self.problem.node_dict[n]['score'] for n in temp_nodes) + 1e-9
            while temp_nodes:
                r = random.uniform(0, total_profit)
                cumulative = 0.0
                chosen = temp_nodes[0]
                for node_id in temp_nodes:
                    cumulative += self.problem.node_dict[node_id]['score']
                    if r <= cumulative:
                        chosen = node_id
                        break
                insertion_list.append(chosen)
                temp_nodes.remove(chosen)
                total_profit -= self.problem.node_dict[chosen]['score']

        elif strategy == 'random':
            insertion_list = list(unvisited)
            random.shuffle(insertion_list)

        elif strategy == 'lrfi':
            # Insert last removed nodes first if they are still unvisited
            lrfi_candidates = [n for n in self.last_removed_nodes if n in unvisited]
            # Remove them from unvisited
            remainder = list(unvisited - set(lrfi_candidates))
            # For remainder, fallback to random (or another strategy if desired)
            random.shuffle(remainder)
            insertion_list = lrfi_candidates + remainder

        else:
            # Default fallback - random
            insertion_list = list(unvisited)
            random.shuffle(insertion_list)

        return insertion_list


    def _compute_min_incremental_time(self, solution, node):
        """
        Compute the minimal incremental travel time of inserting 'node' anywhere in the given 'solution'.
        """
        min_increment = float('inf')
        dm = self.problem.distance_matrix
        for r_idx, route in enumerate(solution):
            for i in range(len(route)-1):
                a, b = route[i], route[i+1]
                current_time = dm[a][b]
                new_time = dm[a][node] + dm[node][b]
                increment = new_time - current_time
                if increment < min_increment:
                    min_increment = increment
        return min_increment if min_increment != float('inf') else 1e9  # Large number if no feasible insertion

    # Insertion methods
    def _insert_nodes_first_available(self, solution, nodes):
        # For each node, insert at the first feasible position in some route
        for node in nodes:
            # Try each route in order, from start to end
            inserted = False
            for route in solution:
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        self._insert_node_in_position(route, pos, node)
                        inserted = True
                        break
                if inserted:
                    break
        return solution

    def _insert_nodes_last_available(self, solution, nodes):
        # For each node, insert at the last feasible position scanning routes from end to start
        for node in nodes:
            inserted = False
            for route in solution:
                for pos in range(len(route)-1, 0, -1):
                    if self._is_feasible_insertion(route, pos, node):
                        self._insert_node_in_position(route, pos, node)
                        inserted = True
                        break
                if inserted:
                    break
        return solution

    def _insert_nodes_random_available(self, solution, nodes):
        # For each node, find all feasible positions and choose one at random
        for node in nodes:
            candidates = []
            for r_idx, route in enumerate(solution):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        candidates.append((r_idx, pos))
            if candidates:
                r_idx, pos = random.choice(candidates)
                self._insert_node_in_position(solution[r_idx], pos, node)
        return solution

    def _insert_nodes_best_overall_position(self, solution, nodes):
        # For each node, test all feasible insertions and choose the one minimizing total solution travel time
        # This can be expensive, but we do it as described.
        original_time = self._compute_solution_travel_time(solution)
        for node in nodes:
            best_delta = float('inf')
            best_route = None
            best_pos = None
            for r_idx, route in enumerate(solution):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        # Insert temporarily and check total time
                        temp_sol = copy.deepcopy(solution)
                        self._insert_node_in_position(temp_sol[r_idx], pos, node)
                        new_time = self._compute_solution_travel_time(temp_sol)
                        delta = new_time - original_time
                        if delta < best_delta:
                            best_delta = delta
                            best_route = r_idx
                            best_pos = pos
            if best_route is not None:
                self._insert_node_in_position(solution[best_route], best_pos, node)
                # Update original_time after insertion
                original_time += best_delta
        return solution

    def _insert_nodes_best_position(self, solution, nodes):
        # For each node, find the insertion that minimizes local incremental time
        for node in nodes:
            best_increment = float('inf')
            best_route = None
            best_pos = None
            for r_idx, route in enumerate(solution):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        increment = self._incremental_time_for_insertion(route, pos, node)
                        if increment < best_increment:
                            best_increment = increment
                            best_route = r_idx
                            best_pos = pos
            if best_route is not None:
                self._insert_node_in_position(solution[best_route], best_pos, node)
        return solution
    def evaluate_solution(self, solution):
        visited = set()
        for route in solution:
            for nid in route:
                visited.add(nid)
                
        total_score = 0.0
        for nid in visited:
            total_score += self.problem.node_dict[nid]['score']
        
        return total_score
    
    def apply_local_search(self, solution):
        """
        Apply local search procedures on the solution, as described in the paper:
        1. Apply a complete 2-opt procedure on each route.
        2. Try inserting randomly selected non-inserted nodes using "Best position insertion".
        3. Randomly select two inserted nodes i, j and one non-inserted node k, remove i and j,
        then try inserting k, i, j in a way to improve the solution.
        4. Randomly select two inserted nodes from different routes and try to swap them.
        
        If the solution is not improved after these moves, it gets rejected and the original solution is returned.
        """
        logging.info("Applying local search procedures...")
        
        original_solution = copy.deepcopy(solution)
        original_value = self.evaluate_solution(original_solution)
        best_solution = copy.deepcopy(original_solution)
        best_value = original_value

        # 1. Apply complete 2-opt to each route
        sol_2opt = self._apply_2opt(best_solution)
        val_2opt = self.evaluate_solution(sol_2opt)
        if val_2opt > best_value:
            best_solution = copy.deepcopy(sol_2opt)
            best_value = val_2opt
        
        # 2. Try inserting non-inserted nodes with "Best position insertion"
        sol_insert = self._try_inserting_non_inserted(best_solution)
        val_insert = self.evaluate_solution(sol_insert)
        if val_insert > best_value:
            best_solution = copy.deepcopy(sol_insert)
            best_value = val_insert
        
        # 3. Remove two inserted nodes i, j and insert a non-inserted node k, then i and j again
        sol_replace = self._replace_two_inserted_with_one_non_inserted(best_solution)
        val_replace = self.evaluate_solution(sol_replace)
        if val_replace > best_value:
            best_solution = copy.deepcopy(sol_replace)
            best_value = val_replace
        
        # 4. Swap two inserted nodes from different routes
        sol_swap = self._swap_inserted_nodes(best_solution)
        val_swap = self.evaluate_solution(sol_swap)
        if val_swap > best_value:
            best_solution = copy.deepcopy(sol_swap)
            best_value = val_swap

        # Check if any improvement was made
        if best_value > original_value:
            logging.info("Local search improved the solution.")
            return best_solution
        else:
            logging.info("Local search did not improve the solution. Reverting to original.")
            return original_solution

    def _apply_2opt(self, solution):

        """
        Apply a complete 2-opt procedure to each route in the solution to reduce travel time.
        The 2-opt heuristic repeatedly attempts to find two edges (i,i+1) and (j,j+1) in a route,
        and if reversing the segment between them reduces the total route travel time, it applies that change.
        
        :param solution: A list of routes (each route is a list of node IDs).
        :return: A new solution after attempting 2-opt improvements on each route.
        """
        improved_solution = [list(route) for route in solution]  # Deep copy
        improved = True
        while improved:
            improved = False
            for r_idx, route in enumerate(improved_solution):
                # If the route is too short, 2-opt won't apply
                if len(route) < 4:
                    continue

                best_improvement = 0
                best_i = None
                best_j = None
                current_time = self._compute_route_time(route)

                # Try all pairs (i, j) with i < j-1 to ensure non-overlapping edges
                for i in range(1, len(route)-2):
                    for j in range(i+2, len(route)-1):
                        # Current edges: (route[i-1], route[i]) and (route[j], route[j+1])
                        # After reversal: (route[i-1], route[j]) and (route[i], route[j+1])
                        old_dist = (self.problem.distance_matrix[route[i-1]][route[i]] +
                                    self.problem.distance_matrix[route[j]][route[j+1]])
                        new_dist = (self.problem.distance_matrix[route[i-1]][route[j]] +
                                    self.problem.distance_matrix[route[i]][route[j+1]])
                        
                        improvement = old_dist - new_dist
                        if improvement > best_improvement:
                            best_improvement = improvement
                            best_i = i
                            best_j = j

                if best_improvement > 0 and best_i is not None and best_j is not None:
                    # Apply the 2-opt reversal
                    route[best_i:best_j+1] = reversed(route[best_i:best_j+1])
                    improved = True

        return improved_solution

    def _try_inserting_non_inserted(self, solution):
        """
        Randomly select some non-inserted nodes and try inserting them
        with the "Best position insertion" operator.

        Best position insertion:
        - For each selected non-inserted node, try all feasible insertions (route, pos).
        - Insert it where it yields the highest improvement in the solution's objective value.
        
        :param solution: Current solution (list of routes)
        :return: Improved solution after attempting these insertions
        """
        improved_solution = copy.deepcopy(solution)
        original_value = self.evaluate_solution(improved_solution)
        best_solution = copy.deepcopy(improved_solution)
        best_value = original_value

        visited = {n for route in best_solution for n in route}
        start_node = self.problem.original_start_id
        end_node = self.problem.original_end_id
        all_nodes = set(self.problem.node_dict.keys())
        non_inserted = list(all_nodes - visited - {start_node, end_node})

        # Shuffle non_inserted for randomness and limit the number of attempts
        random.shuffle(non_inserted)
        # For efficiency, we only attempt a subset, say up to 10 nodes
        non_inserted = non_inserted[:10]

        for node in non_inserted:
            # Attempt to insert this node in the best possible position
            temp_best_solution = None
            temp_best_value = best_value

            # Try all routes and all feasible positions
            for r_idx, route in enumerate(best_solution):
                for pos in range(1, len(route)):  # Avoid placing before start or after end
                    if self._is_feasible_insertion(route, pos, node):
                        # Test insertion
                        trial_solution = copy.deepcopy(best_solution)
                        self._insert_node_in_position(trial_solution[r_idx], pos, node)
                        val = self.evaluate_solution(trial_solution)
                        
                        if val > temp_best_value:
                            temp_best_value = val
                            temp_best_solution = trial_solution

            # After checking all positions, if we found an improvement, update best_solution
            if temp_best_solution is not None and temp_best_value > best_value:
                best_value = temp_best_value
                best_solution = temp_best_solution

        return best_solution


    def _replace_two_inserted_with_one_non_inserted(self, solution):
        """
        Randomly select two inserted nodes i and j and one non-inserted node k.
        Remove i and j, then try inserting k, followed by reinserting i and j
        to improve the solution value.
        
        :param solution: Current solution
        :return: Modified solution after this heuristic
        """
        original_solution = copy.deepcopy(solution)
        original_value = self.evaluate_solution(original_solution)
        best_solution = copy.deepcopy(original_solution)
        best_value = original_value

        visited = {n for route in original_solution for n in route}
        start_node = self.problem.original_start_id
        end_node = self.problem.original_end_id
        all_nodes = set(self.problem.node_dict.keys())
        inserted = list(visited - {start_node, end_node})
        non_inserted = list(all_nodes - visited - {start_node, end_node})

        # Check if we have enough nodes to attempt
        if len(inserted) < 2 or len(non_inserted) < 1:
            return best_solution  # Cannot perform this operation

        # Select i, j from inserted, k from non_inserted
        i_node, j_node = random.sample(inserted, 2)
        k_node = random.choice(non_inserted)

        # Remove i_node and j_node
        temp_solution = copy.deepcopy(original_solution)
        for route in temp_solution:
            route[:] = [x for x in route if x not in (i_node, j_node)]

        # Insert k_node (best position insertion)
        inserted_k = False
        temp_best_value = self.evaluate_solution(temp_solution)
        temp_best_sol = copy.deepcopy(temp_solution)

        for r_idx, route in enumerate(temp_solution):
            for pos in range(1, len(route)):
                if self._is_feasible_insertion(route, pos, k_node):
                    trial_sol = copy.deepcopy(temp_solution)
                    self._insert_node_in_position(trial_sol[r_idx], pos, k_node)
                    val = self.evaluate_solution(trial_sol)
                    if val > temp_best_value:
                        temp_best_value = val
                        temp_best_sol = trial_sol
                        inserted_k = True

        if not inserted_k:
            # Could not insert k anywhere, revert
            return best_solution

        # Now temp_best_sol is the solution with k inserted at its best position
        # Try reinserting i and j using best position insertion
        def best_position_insert(node, current_sol, current_val):
            best_val = current_val
            best_ins_sol = copy.deepcopy(current_sol)
            for r_idx, route in enumerate(current_sol):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        trial_sol = copy.deepcopy(current_sol)
                        self._insert_node_in_position(trial_sol[r_idx], pos, node)
                        val = self.evaluate_solution(trial_sol)
                        if val > best_val:
                            best_val = val
                            best_ins_sol = trial_sol
            return best_ins_sol, best_val

        # Insert i_node
        temp_sol_i, val_i = best_position_insert(i_node, temp_best_sol, temp_best_value)
        # Insert j_node (in the solution after i_node is reinserted)
        temp_sol_j, val_j = best_position_insert(j_node, temp_sol_i, val_i)

        # Check improvement
        if val_j > best_value:
            best_value = val_j
            best_solution = temp_sol_j

        return best_solution

    def _swap_inserted_nodes(self, solution):
        """
        Randomly select two inserted nodes served by different routes and attempt to swap them
        to reduce total travel time.
        
        :param solution: Current solution (list of routes)
        :return: Modified solution after attempting swaps
        """
        original_solution = copy.deepcopy(solution)
        original_time = self._compute_solution_travel_time(original_solution)
        best_solution = copy.deepcopy(original_solution)
        best_time = original_time

        start_node = self.problem.original_start_id
        end_node = self.problem.original_end_id

        # Identify inserted nodes and their positions
        inserted_positions = []  # list of (node, route_index, position_in_route)
        for r_idx, route in enumerate(original_solution):
            for pos, nid in enumerate(route):
                if nid not in (start_node, end_node):
                    inserted_positions.append((nid, r_idx, pos))
        
        if len(inserted_positions) < 2:
            # Not enough inserted nodes to attempt a swap
            return best_solution

        # Limit attempts for efficiency
        attempts = min(10, (len(inserted_positions)*(len(inserted_positions)-1))//2)
        tried_pairs = set()

        for _ in range(attempts):
            n1, r1, p1 = random.choice(inserted_positions)
            n2, r2, p2 = random.choice(inserted_positions)
            
            # Ensure distinct nodes and different routes
            if n1 == n2 or r1 == r2:
                continue
            
            pair_key = tuple(sorted([n1, n2]))
            if pair_key in tried_pairs:
                continue
            tried_pairs.add(pair_key)

            # Attempt swap
            trial_solution = copy.deepcopy(best_solution)
            trial_solution[r1][p1], trial_solution[r2][p2] = trial_solution[r2][p2], trial_solution[r1][p1]

            val = self._compute_solution_travel_time(trial_solution)
            # Since we want to reduce travel time, an improvement means val < best_time
            if val < best_time:
                best_time = val
                best_solution = trial_solution

        return best_solution

    

    def generate_and_solve_SROP(self, solution):
        """
        Generate and solve a  Sub-Route Optimization Problem (SROP) with potential subtour elimination callback.
        
        :param solution: Current solution (a list of routes)
        :return: Optimized solution
        """
        logging.info("Generating and solving SORP...")

        # Select a route to optimize (e.g., longest route)
        if not solution or all(len(r) <= 2 for r in solution):
            return copy.deepcopy(solution)
        for route_to_optimize in solution: #= max(solution, key=lambda r: len(r))
            start_node = route_to_optimize[0]
            end_node = route_to_optimize[-1]

            # Identify all nodes currently served by the solution
            served_nodes = set()
            for route in solution:
                served_nodes.update(route)
            served_nodes.discard(start_node)
            served_nodes.discard(end_node)

            # Identify unselected (unserved) nodes
            all_nodes = set(self.problem.node_dict.keys())
            unselected_nodes = all_nodes - served_nodes - {start_node, end_node}

            # Define V as the union of nodes in the selected route and unselected nodes
            V = set(route_to_optimize).union(unselected_nodes)


            # Build arcs A and data tij, pi
            A = []
            tij = {}
            pi = {}
            node_list = list(V)

            for i in node_list:
                pi[i] = self.problem.node_dict[i]['score'] if i not in (start_node, end_node) else 0.0
                for j in node_list:
                    if i != j:
                        A.append((i,j))
                        tij[i,j] = self.problem.distance_matrix[i][j]

            # Compute original route time to set Dmax
            original_time = 0.0
            for i in range(len(route_to_optimize)-1):
                original_time += self.problem.distance_matrix[route_to_optimize[i]][route_to_optimize[i+1]]
            Dmax = original_time

            # Build SROP model
            m = gp.Model("SROP")
            m.Params.LazyConstraints = 1

            x = m.addVars(A, vtype=GRB.BINARY, name="x")
            y = m.addVars(V, vtype=GRB.BINARY, name="y")

            # Objective: maximize profit
            m.setObjective(gp.quicksum(pi[i]*y[i] for i in V if i not in {start_node, end_node}), GRB.MAXIMIZE)

            # Start depot:
            m.addConstr(gp.quicksum(x[start_node,j] for j in V if (start_node,j) in A) == 1)
            # End depot:
            m.addConstr(gp.quicksum(x[i,end_node] for i in V if (i,end_node) in A) == 1)

            # Flow and linking:
            for i in V:
                if i not in {start_node, end_node}:
                    m.addConstr(gp.quicksum(x[i,j] for j in V if (i,j) in A) == y[i])
                    m.addConstr(gp.quicksum(x[j,i] for j in V if (j,i) in A) == y[i])

            # Time constraint:
            m.addConstr(gp.quicksum(tij[i,j]*x[i,j] for (i,j) in A) <= Dmax)

            # Store data for callback
            m._x = x
            m._V = V
            m._A = A
            m._start_node = start_node
            m._end_node = end_node

            m.optimize(self.srop_subtour_callback)

            if m.status == GRB.OPTIMAL:
                logging.info("SROP Optimal solution found with objective:", m.objVal)
                x_sol = m.getAttr('x', x)
            
                # Reconstruct path
                # Step 1: Build a mapping from each node to its next node
                next_node = {}
                for (i, j), val in x_sol.items():
                    if val > 0.9:
                        if i in next_node:
                            logging.info(f"Warning: Multiple outgoing arcs detected from node {i}.")
                        next_node[i] = j
                # Step 2: Reconstruct the path using the mapping
                path = [start_node]
                current = start_node
                
                while current != end_node :
                    if current not in next_node:
                        logging.info(f"Error: No outgoing arc from node {current}. Incomplete path.")
                        break  
                    next_j = next_node[current]
                    path.append(next_j)
                    current = next_j

                
                if current != end_node:
                    logging.info(f"Error: Route reconstruction incomplete. Reached node {current} instead of {end_node}.")
                    
                
                # Step 3: Calculate the profit of the optimized route
                optimized_profit = sum(self.problem.node_dict[n]['score'] for n in path if n not in {start_node, end_node})
                original_profit = sum(self.problem.node_dict[n]['score'] for n in route_to_optimize if n not in {start_node, end_node})

                logging.info(f"Original Route Profit: {original_profit}, Optimized Route Profit: {optimized_profit}")

                # Step 4: Replace the route only if the optimized profit is greater or equal
                if optimized_profit >= original_profit:
                    new_solution = copy.deepcopy(solution)
                    route_index = solution.index(route_to_optimize)
                    new_solution[route_index] = path
                    logging.info("SROP completed and route optimized.")
                    self.add_route_if_unique(path)
                    
                else:
                    logging.info("SROP did not find an improved or equal solution. Retaining the original route.")
                    new_solution =  copy.deepcopy(solution)
            else:
                logging.info("SROP no improvement or no feasible solution found.")
                new_solution =  copy.deepcopy(solution)
            
        return new_solution

    def generate_and_solve_SPP(self):
        """
        Solve the Set Packing Problem (SPP) to select |L| routes from the collected routes that maximize total profit.

        :return: Final optimized solution (list of routes) or None if no solution is found.
        """
        logging.info("Generating and solving SPP...")

        if not self.routes_list:
            logging.warning("No routes collected for SPP.")
            return None

        R = range(len(self.routes_list))  # Route indices
        num_vehicles = self.problem.P        # Number of vehicles (paths), from ProblemInstance
        nodes = set()
        for _, _, coverage in self.routes_list:
            nodes.update(coverage.keys())

        m = gp.Model("SPP")
        m.setParam('OutputFlag', 0)  # Suppress Gurobi output for cleaner logs

        # Decision Variables
        z = m.addVars(R, vtype=GRB.BINARY, name="z")

        # Objective: Maximize total profit
        m.setObjective(gp.quicksum(self.routes_list[r][1] * z[r] for r in R), GRB.MAXIMIZE)

        # Constraints:
        # Each node is served at most once
        for i in nodes:
            m.addConstr(
                gp.quicksum(self.routes_list[r][2].get(i, 0) * z[r] for r in R) <= 1,
                name=f"node_{i}_coverage"
            )

        # Exactly |L| routes are selected
        m.addConstr(
            gp.quicksum(z[r] for r in R) == num_vehicles,
            name="exact_routes_selected"
        )

        # Optimize the model
        m.optimize()

        if m.status == GRB.OPTIMAL:
            logging.info(f"SPP Optimal solution found with total profit: {m.objVal}")
            chosen_routes = [r for r in R if z[r].X > 0.9]
            final_solution = self.build_solution_from_routes(chosen_routes)
            logging.info(f"Selected {len(final_solution)} routes for the final solution.")
            return final_solution
        else:
            logging.warning("No optimal solution found for SPP.")
            return None

        
    def add_route_if_unique(self, route):
        """
        Add a route to the routes_list and generated_routes if it's unique.
        
        :param route: List of node IDs representing the route.
        """
        # Create a frozenset of nodes to check uniqueness (order doesn't matter)
        route_nodes = frozenset(route)
        if route_nodes not in self.generated_routes:
            self.generated_routes.add(route_nodes)
            # Calculate profit (sum of node scores, excluding start and end)
            profit = sum(self.problem.node_dict[n]['score'] for n in route if n not in {self.problem.original_start_id, self.problem.original_end_id})
            # Create coverage dictionary {node:1}
            coverage = {n: 1 for n in route if n not in {self.problem.original_start_id, self.problem.original_end_id}}
            # Append to routes_list
            self.routes_list.append((route, profit, coverage))
            logging.info(f"Added new unique route with profit {profit}.")

    def build_solution_from_routes(self, chosen_route_indices):
        """
        Build the final solution from the selected routes.
        
        :param chosen_route_indices: List of indices representing chosen routes in routes_list.
        :return: Final solution as a list of routes.
        """
        final_solution = []
        for idx in chosen_route_indices:
            route = self.routes_list[idx][0]  # Extract the route
            final_solution.append(route)
        return final_solution
        
    def update_scores(self):
        """
        Update the scores of the ALNS operators and insertion strategies at the end of a segment.
        
        p_{k,q+1} = kappa * (observed_score_k / n_k) + (1 - kappa)*p_{k,q}, if n_k > 0
        If n_k = 0, score remains unchanged.
        After updating, observed scores and counts reset.
        """
        logging.info("Updating scores of the ALNS operators and insertion strategies...")

        kappa = self.params.get('kappa', 0.5)

        def update_category_scores(scores, observed_scores, counts):
            for k in scores.keys():
                n_k = counts[k]
                if n_k > 0:
                    old_score = scores[k]
                    new_score = kappa * (observed_scores[k] / n_k) + (1 - kappa) * old_score
                    scores[k] = new_score
                # Reset for next segment
                observed_scores[k] = 0.0
                counts[k] = 0

        update_category_scores(self.selection_scores, self.selection_observed_scores, self.selection_counts)
        update_category_scores(self.removal_scores, self.removal_observed_scores, self.removal_counts)
        update_category_scores(self.insertion_scores, self.insertion_observed_scores, self.insertion_counts)

        logging.info("Score update completed.")
        
    def run(self):
            # Step 1: Apply node elimination procedure
            self.node_elimination_procedure()
            
            # Step 2: Construct initial solution using the nearest neighbor algorithm
            initial_solution = self.construct_initial_solution()
            self.s_best = initial_solution
            self.s_adm = initial_solution
            
            # Initialize parameters
            self.T = self.params['T0']
            self.seg = 0
            self.iteration_best = 0
            
            # Step 4: Initialize scores
            self.initialize_scores()

            # Extract q parameters
            q1 = self.params.get('q1', 10.0)
            q2 = self.params.get('q2', 5.0)
            q3 = self.params.get('q3', 1.0)

            # Step 5: Main loop
            while self.seg < self.params['Nseg'] and self.iteration_best < self.params['iteration_best_max']:
                logging.info(f"\n--- Segment {self.seg + 1} ---")
                iteration = 0
                
                while iteration < self.params['iteration_max']:
                    logging.info(f"\nIteration {iteration + 1} within Segment {self.seg + 1}")
                    s = copy.deepcopy(self.s_adm)
                    
                    # Generate b (number of nodes to remove)
                    # For safety, ensure b does not exceed solution complexity; using a simple logic:
                    b = random.randint(1, max(1, int(0.25*sum(len(p) for p in s)-2*len(s))))
                    ratio_sequence_to_remove = self.params['ratio_sequence_to_remove']
                    logging.info(f"Number of nodes to remove: {b}")
                    
                    # Select node selection strategy
                    c = self.select_node_selection_strategy()
                    
                    # Select removal and insertion operators
                    R, I = self.select_removal_insertion_operators()
                    
                    # Count usage
                    self.selection_counts[c] += 1
                    self.removal_counts[R] += 1
                    self.insertion_counts[I] += 1

                    # Remove b nodes using R
                    s = self.remove_nodes(s, b, R, ratio_sequence_to_remove)
                    
                    # Insert nodes using I following c
                    s = self.insert_nodes(s, I, c)
                    
                    # Generate a random number d in [0,1]
                    d = random.uniform(0, 1)
                    logging.info(f"Random number d: {d}")
                    
                    # Evaluate solutions
                    f_s = self.evaluate_solution(s)
                    f_sadm = self.evaluate_solution(self.s_adm)
                    f_sbest = self.evaluate_solution(self.s_best)
                    
                    if f_s >= f_sadm or d <= math.exp((f_s - f_sadm) / self.T):
                        logging.info("Solution accepted based on acceptance criteria.")
                        
                        # Determine q increment based on improvement
                        if f_s > f_sbest:
                            q_value = q1
                        elif f_s > f_sadm:
                            q_value = q2
                        else:
                            q_value = q3

                        # Increment observed scores
                        self.selection_observed_scores[c] += q_value
                        self.removal_observed_scores[R] += q_value
                        self.insertion_observed_scores[I] += q_value

                        # If f(s) > f(sadm), apply local search
                        if f_s > f_sadm:
                            s = self.apply_local_search(s)
                            f_s = self.evaluate_solution(s)
                            logging.info("Applied local search.")

                        # If f(s) > f(s_best), update sbest and reset iteration_best
                        if f_s > f_sbest:
                            logging.info("New best solution found. Generating and solving SROP...")
                            s = self.generate_and_solve_SROP(s) 
                            self.s_best = copy.deepcopy(s)
                            self.iteration_best = 0
                            logging.info("s_best updated.")
                        else:
                            self.iteration_best += 1
                            logging.info(f"Iteration best incremented to {self.iteration_best}.")
                        
                        self.s_adm = copy.deepcopy(s)
                    else:
                        # Not accepted
                        self.iteration_best += 1
                        logging.info(f"Solution not accepted. Iteration best incremented to {self.iteration_best}.")
                    
                    # Temperature check
                    if self.T <= self.params['T_min']:
                        logging.info("Temperature below minimum. Resetting temperature and generating SPP...")
                        self.T = self.params['T0']
                        logging.info(self.routes_list)
                        s = self.generate_and_solve_SPP()
                        
                        if self.evaluate_solution(s) > self.evaluate_solution(self.s_best):
                            self.iteration_best = 0
                            logging.info("Improved solution found after SPP.")
                        
                        self.s_best = copy.deepcopy(s)
                        self.s_adm = copy.deepcopy(s)
                    
                    # Update temperature and iteration
                    self.T *= self.params['cooling_rate']
                    iteration += 1
                    logging.info(f"Temperature updated to {self.T}.")
                
                # Update scores at the end of the segment
                self.update_scores()
                
                # Increment segment
                self.seg += 1
                logging.info(f"Segment {self.seg} completed.")
            
            # Generate and solve a final SPP
            logging.info("Route List: ",  self.routes_list)
            logging.info("\nGenerating and solving final SPP...")
            self.s_best = self.generate_and_solve_SPP()
            
            if self.s_best is None:
                logging.warning("No best solution found. Returning a trivial empty solution to avoid None.")
                self.s_best = [[self.problem.original_start_id, self.problem.original_end_id] for _ in range(self.problem.P) ]
    
            # Final solution
            logging.info("Final solution obtained.")
            return self.s_best

# %%
if __name__ == "__main__":
    # Define the path to your TOP instance data file
    file_path = 'Set_100_234/p4.2.a.txt' # 3 paths does not properly work currently!

    parameters = {
        'T0': 95,              # Initial temperature for the simulated annealing mechanism.
        'T_min': 0.0001,              # Minimum temperature below which we reset temperature and solve a SPP.
        'cooling_rate': 0.9999,    # The factor by which the temperature is multiplied after each iteration.
        'Nseg': 100,              # Number of segments (run segments) after which score updates occur.
        'iteration_max': 1000,  # Maximum number of iterations per segment.
        'iteration_best_max': 50,# Maximum number of consecutive iterations without improvement before stopping.
        'kappa': 0.85,            # Reaction factor for updating operator/strategy scores.
        'q1': 20.0,              # Score increment if a new best solution is found.
        'q2': 5.0,               # Score increment if the solution improves the last admissible one but is not a best.
        'q3': 1.0,               # Score increment if the solution is accepted but does not improve the last admissible.
        'lrfi_count': 10,         # Maximum number of nodes to track for "Last Removed First Inserted" strategy.
        'ratio_sequence_to_remove': 0.15 # Random size of the sequence to remove
    }

    # Initialize HALNS heuristic with the problem instance file and parameters
    halns = HALNS(file_path, parameters)

    # Run HALNS to obtain the best solution
    best_solution = halns.run()

    # Output the best solution
    print("Best Solution:", best_solution)

    total_prize = halns.evaluate_solution(best_solution)
    print("Total Prize Collected:", total_prize)
# Out:
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x75619038
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 82 columns
# Presolve time: 0.05s
# Presolved: 59 rows, 818 columns, 2366 nonzeros
# Variable types: 0 continuous, 818 integer (818 binary)
#
# Root relaxation: objective 2.367258e+02, 120 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  236.72580    0    4   -0.00000  236.72580      -     -    0s
#      0     0  191.16894    0   18   -0.00000  191.16894      -     -    0s
#      0     0  191.08675    0   16   -0.00000  191.08675      -     -    0s
# H    0     0                      24.0000000  191.08675   696%     -    0s
#      0     0  187.58002    0   16   24.00000  187.58002   682%     -    0s
#      0     2  187.58002    0   16   24.00000  187.58002   682%     -    0s
# H  154    83                      90.0000000  166.83639  85.4%   8.0    0s
# *  985    13              29     100.0000000  119.15458  19.2%   8.1    0s
#
# Cutting planes:
#   Cover: 5
#   MIR: 2
#   Inf proof: 33
#   Lazy constraints: 57
#
# Explored 1088 nodes (8682 simplex iterations) in 0.81 seconds (0.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 100 90 24 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.000000000000e+02, best bound 1.000000000000e+02, gap 0.0000%
#
# User-callback calls 2587, time in user-callback 0.07 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0xefcac6c6
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 77 columns
# Presolve time: 0.13s
# Presolved: 59 rows, 823 columns, 2379 nonzeros
# Variable types: 0 continuous, 823 integer (823 binary)
#
# Root relaxation: objective 1.988934e+02, 114 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  198.89342    0    4   -0.00000  198.89342      -     -    0s
#      0     0  170.47500    0    4   -0.00000  170.47500      -     -    0s
#      0     0  151.68959    0   30   -0.00000  151.68959      -     -    0s
#      0     0  150.49752    0   30   -0.00000  150.49752      -     -    0s
#      0     0  150.49752    0   33   -0.00000  150.49752      -     -    0s
#      0     0  145.68670    0   29   -0.00000  145.68670      -     -    0s
#      0     2  135.44196    0   33   -0.00000  135.44196      -     -    0s
# H  234    94                      46.0000000  129.86306   182%   7.0    0s
# *  642   198              15      66.0000000  108.89930  65.0%   6.8    0s
# H  743   188                      78.0000000  106.73444  36.8%   6.9    0s
# H  990    33                      90.0000000   93.31731  3.69%   7.1    0s
#
# Cutting planes:
#   Cover: 8
#   MIR: 3
#   Inf proof: 2
#   Lazy constraints: 65
#
# Explored 1156 nodes (7791 simplex iterations) in 1.02 seconds (0.33 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 90 78 66 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.000000000000e+01, best bound 9.000000000000e+01, gap 0.0000%
#
# User-callback calls 2845, time in user-callback 0.09 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55 rows, 784 columns and 2266 nonzeros
# Model fingerprint: 0x5ac35df6
# Variable types: 0 continuous, 784 integer (784 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 73 columns
# Presolve time: 0.04s
# Presolved: 55 rows, 711 columns, 2053 nonzeros
# Variable types: 0 continuous, 711 integer (711 binary)
#
# Root relaxation: objective 2.293019e+02, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  229.30188    0    4   -0.00000  229.30188      -     -    0s
#      0     0  209.60420    0    6   -0.00000  209.60420      -     -    0s
#      0     0  196.87958    0   32   -0.00000  196.87958      -     -    0s
# H    0     0                      24.0000000  196.87958   720%     -    0s
#      0     0  192.93196    0   32   24.00000  192.93196   704%     -    0s
#      0     2  192.93196    0   32   24.00000  192.93196   704%     -    0s
# H  970   384                      62.0000000  152.26312   146%   7.4    0s
# H 2423   351                      83.0000000  127.68142  53.8%   8.7    1s
# H 2442   314                      90.0000000  127.66964  41.9%   8.8    1s
# H 2797   205                      91.0000000  119.27019  31.1%   8.9    1s
# * 2798   204              23      92.0000000  119.27019  29.6%   8.9    1s
# H 2831   171                     100.0000000  119.05482  19.1%   8.9    1s
# * 2859   171              21     103.0000000  118.80662  15.3%   8.9    1s
#
# Cutting planes:
#   Cover: 5
#   Inf proof: 12
#   Lazy constraints: 105
#
# Explored 3108 nodes (27147 simplex iterations) in 1.54 seconds (0.78 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 103 100 92 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 6766, time in user-callback 0.13 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x97b2239a
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 51 columns
# Presolve time: 0.04s
# Presolved: 59 rows, 849 columns, 2457 nonzeros
# Variable types: 0 continuous, 849 integer (849 binary)
#
# Root relaxation: objective 2.045674e+02, 112 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  204.56737    0    4   -0.00000  204.56737      -     -    0s
#      0     0  171.54649    0   24   -0.00000  171.54649      -     -    0s
#      0     0  167.18201    0   18   -0.00000  167.18201      -     -    0s
#      0     0  167.18201    0   18   -0.00000  167.18201      -     -    0s
#      0     0  160.00967    0   18   -0.00000  160.00967      -     -    0s
#      0     2  160.00967    0   18   -0.00000  160.00967      -     -    0s
# H  166    89                      74.0000000  127.43949  72.2%   8.5    0s
# H  358   126                      79.0000000  117.66636  48.9%   7.2    0s
# H  363   125                      82.0000000  117.66636  43.5%   7.1    0s
# H  454   123                      90.0000000  115.20063  28.0%   7.2    0s
# *  534   107              20      91.0000000  112.04059  23.1%   7.4    0s
#
# Cutting planes:
#   Cover: 2
#   MIR: 3
#   StrongCG: 1
#   Inf proof: 24
#   Lazy constraints: 59
#
# Explored 796 nodes (5674 simplex iterations) in 0.68 seconds (0.25 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 91 90 82 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.100000000000e+01, best bound 9.100000000000e+01, gap 0.0000%
#
# User-callback calls 2035, time in user-callback 0.08 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x4463c9cd
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 69 columns
# Presolve time: 0.04s
# Presolved: 59 rows, 831 columns, 2405 nonzeros
# Variable types: 0 continuous, 831 integer (831 binary)
#
# Root relaxation: objective 2.230184e+02, 113 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  223.01840    0    4   -0.00000  223.01840      -     -    0s
#      0     0  194.84211    0   19   -0.00000  194.84211      -     -    0s
#      0     2  188.98890    0   19   -0.00000  188.98890      -     -    0s
# H  167    91                      90.0000000  142.42736  58.3%   8.0    0s
# H  177    91                      91.0000000  142.42736  56.5%   7.7    0s
# H  650   124                     103.0000000  126.72948  23.0%   7.9    0s
#
# Cutting planes:
#   Cover: 2
#   Inf proof: 22
#   Lazy constraints: 53
#
# Explored 889 nodes (7020 simplex iterations) in 0.63 seconds (0.26 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 103 91 90 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 2133, time in user-callback 0.06 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55 rows, 784 columns and 2266 nonzeros
# Model fingerprint: 0xb57a0a85
# Variable types: 0 continuous, 784 integer (784 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 71 columns
# Presolve time: 0.04s
# Presolved: 55 rows, 713 columns, 2057 nonzeros
# Variable types: 0 continuous, 713 integer (713 binary)
#
# Root relaxation: objective 2.289690e+02, 105 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  228.96904    0    4   -0.00000  228.96904      -     -    0s
#      0     0  209.32335    0    6   -0.00000  209.32335      -     -    0s
#      0     0  195.24831    0   31   -0.00000  195.24831      -     -    0s
#      0     0  195.24831    0   34   -0.00000  195.24831      -     -    0s
#      0     0  191.94980    0   35   -0.00000  191.94980      -     -    0s
# H    0     0                      35.0000000  191.94980   448%     -    0s
#      0     0  190.31975    0   33   35.00000  190.31975   444%     -    0s
#      0     0  190.31975    0   36   35.00000  190.31975   444%     -    0s
#      0     0  185.85038    0   36   35.00000  185.85038   431%     -    0s
#      0     2  185.85038    0   33   35.00000  185.85038   431%     -    0s
# H  122    53                      64.0000000  169.21894   164%   7.5    0s
# H 1334   297                      85.0000000  139.13125  63.7%   7.5    0s
# H 1425   240                     100.0000000  136.69876  36.7%   7.7    0s
# * 1994   128               8     103.0000000  118.43302  15.0%   8.0    1s
#
# Cutting planes:
#   Cover: 4
#   MIR: 4
#   Inf proof: 20
#   Lazy constraints: 94
#
# Explored 2180 nodes (17285 simplex iterations) in 1.13 seconds (0.56 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 103 100 85 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 4887, time in user-callback 0.11 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x0a19fa3d
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 72 columns
# Presolve time: 0.04s
# Presolved: 59 rows, 828 columns, 2396 nonzeros
# Variable types: 0 continuous, 828 integer (828 binary)
#
# Root relaxation: objective 2.219260e+02, 119 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  221.92596    0    4   -0.00000  221.92596      -     -    0s
# H    0     0                      17.0000000  221.92596  1205%     -    0s
#      0     0  189.83881    0   20   17.00000  189.83881  1017%     -    0s
#      0     0  189.76307    0   14   17.00000  189.76307  1016%     -    0s
#      0     0  171.91385    0   28   17.00000  171.91385   911%     -    0s
#      0     2  164.30223    0   28   17.00000  164.30223   866%     -    0s
# H   79    48                      55.0000000  152.28251   177%   8.4    0s
# H  112    52                      82.0000000  145.68430  77.7%   8.3    0s
# H  441   114                      90.0000000  128.51064  42.8%   7.1    0s
# H  473   114                      98.0000000  128.50593  31.1%   7.0    0s
# *  474   114              13      99.0000000  128.50593  29.8%   7.0    0s
#
# Cutting planes:
#   Cover: 1
#   MIR: 1
#   Inf proof: 25
#   Lazy constraints: 48
#
# Explored 720 nodes (4946 simplex iterations) in 0.67 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 99 98 90 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.900000000000e+01, best bound 9.900000000000e+01, gap 0.0000%
#
# User-callback calls 1815, time in user-callback 0.10 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 57 rows, 841 columns and 2434 nonzeros
# Model fingerprint: 0x1377c3fa
# Variable types: 0 continuous, 841 integer (841 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 101 columns
# Presolve time: 0.04s
# Presolved: 57 rows, 740 columns, 2144 nonzeros
# Variable types: 0 continuous, 740 integer (740 binary)
#
# Root relaxation: objective 2.039887e+02, 106 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  203.98866    0    4   -0.00000  203.98866      -     -    0s
#      0     0  163.31644    0   12   -0.00000  163.31644      -     -    0s
#      0     0  144.00488    0   21   -0.00000  144.00488      -     -    0s
#      0     0  142.84743    0   34   -0.00000  142.84743      -     -    0s
#      0     0  142.84743    0   36   -0.00000  142.84743      -     -    0s
#      0     0  141.78057    0   36   -0.00000  141.78057      -     -    0s
# H    0     0                       4.0000000  136.66705  3317%     -    0s
# H    0     0                      21.0000000  136.01584   548%     -    0s
#      0     2  136.01584    0   31   21.00000  136.01584   548%     -    0s
# H   87    72                      67.0000000  132.03376  97.1%   7.5    0s
# H  115    76                      75.0000000  129.17108  72.2%   8.2    0s
# H  386   112                      76.0000000  115.82520  52.4%   8.0    0s
# *  524   119              22      82.0000000  109.50773  33.5%   7.9    0s
# *  641   120              13     103.0000000  107.28499  4.16%   7.9    0s
#
# Cutting planes:
#   Cover: 1
#   MIR: 2
#   Inf proof: 5
#   Lazy constraints: 67
#
# Explored 823 nodes (5811 simplex iterations) in 0.66 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 103 82 76 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 2106, time in user-callback 0.09 sec
# Best Solution: [[0, 96, 23, 7, 34, 76, 99], [0, 14, 52, 55, 78, 24, 99]]
# Total Prize Collected: 206.0

# %%
def process_all_instances(directory_path):
    """
    Process all instance files in a directory using the HALNS metaheuristic,
    and record results in a CSV file. 

    :param directory_path: Path to the directory containing instance files.
    :return: A list of dictionaries, each containing the results for one instance.
    """
    import csv
    import os
    import time

    # Ensure you import your HALNS class. For example:
    # from src.halns import HALNS

    # Prepare a list to store the results
    results = []

    # Name of the CSV file for storing aggregated results
    csv_file = 'results_halns.csv'
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Write the header row
        writer.writerow(['Instance', 'RunTime', 'Gap', 'TotalCollectedPrize', 'AveragePrizePerVehicle'])

    # Iterate over all files in the directory
    for filename in os.listdir(directory_path):
        if filename.endswith('.txt'):  # Adjust the extension if needed
            file_path = os.path.join(directory_path, filename)
            print(f"\nProcessing instance: {filename}")
            # ---------------------------------------------
            # 2. Initialize the HALNS metaheuristic
            # ---------------------------------------------
            
            params = {
                'T0': 95,              # Initial temperature for the simulated annealing mechanism.
                'T_min': 0.0001,              # Minimum temperature below which we reset temperature and solve a SPP.
                'cooling_rate': 0.9999,    # The factor by which the temperature is multiplied after each iteration.
                'Nseg': 100,              # Number of segments (run segments) after which score updates occur.
                'iteration_max': 1000,  # Maximum number of iterations per segment.
                'iteration_best_max': 50,# Maximum number of consecutive iterations without improvement before stopping.
                'kappa': 0.85,            # Reaction factor for updating operator/strategy scores.
                'q1': 20.0,              # Score increment if a new best solution is found.
                'q2': 5.0,               # Score increment if the solution improves the last admissible one but is not a best.
                'q3': 1.0,               # Score increment if the solution is accepted but does not improve the last admissible.
                'lrfi_count': 10,         # Maximum number of nodes to track for "Last Removed First Inserted" strategy.
                'ratio_sequence_to_remove': 0.15 # Random size of the sequence to remove
            }

            # Start timing
            start_time = time.time()

            # Create HALNS object
            halns_solver = HALNS(file_path=file_path, parameters=params)

            # ---------------------------------------------
            # 3. Run the HALNS metaheuristic
            # ---------------------------------------------
            best_solution = halns_solver.run()

            # End timing
            end_time = time.time()
            run_time = end_time - start_time

            # ---------------------------------------------
            # 4. Compute metrics: total collected prize, average prize per vehicle
            # ---------------------------------------------
            
            total_collected_prize = halns_solver.evaluate_solution(best_solution)

            # The number of vehicles is typically halns_solver.problem.P
            # or directly from the best_solution if it is a list of routes:
            # num_vehicles_used = len(best_solution)
            P = halns_solver.problem.P  # or from your problem data
            if P > 0:
                average_prize = total_collected_prize / P
            else:
                average_prize = 0

            # Gap is not directly computed by HALNS (unlike a MILP solver),
            # so we can store a placeholder value (e.g., 0 or None).
            gap = 0.0

            # ---------------------------------------------
            # 5. Append the results
            # ---------------------------------------------
            results.append({
                'Instance': filename,
                'RunTime': run_time,
                'Gap': gap,
                'TotalCollectedPrize': total_collected_prize,
                'AveragePrizePerVehicle': average_prize
            })

            # Write the results to the CSV file
            with open(csv_file, mode='a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([
                    filename,
                    run_time,
                    gap,
                    total_collected_prize,
                    average_prize
                ])

        else:
            print(f"Skipping non-txt file: {filename}")

    return results

# %%
logging.basicConfig(
    level=logging.WARNING,  # INFO / WORNING
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)
instance_directory = 'Set_100_234'  
results = process_all_instances(instance_directory)
for result in results:
    print(result)
# Out:
# Processing instance: p4.2.a.txt
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x6365a4de
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 77 columns
# Presolve time: 0.04s
# Presolved: 59 rows, 823 columns, 2382 nonzeros
# Variable types: 0 continuous, 823 integer (823 binary)
#
# Root relaxation: objective 2.352704e+02, 100 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  235.27037    0    4   -0.00000  235.27037      -     -    0s
#      0     0  182.69555    0   15   -0.00000  182.69555      -     -    0s
#      0     0  176.83685    0   27   -0.00000  176.83685      -     -    0s
# H    0     0                      13.0000000  176.83685  1260%     -    0s
#      0     0  170.24107    0   27   13.00000  170.24107  1210%     -    0s
#      0     0  168.85674    0   26   13.00000  168.85674  1199%     -    0s
# H    0     0                      32.0000000  168.85674   428%     -    0s
#      0     0  168.44123    0   19   32.00000  168.44123   426%     -    0s
#      0     0  165.78431    0   19   32.00000  165.78431   418%     -    0s
#      0     2  165.78431    0   19   32.00000  165.78431   418%     -    0s
# H  149    84                      71.0000000  155.51672   119%   8.9    0s
# H  916   382                      89.0000000  143.52426  61.3%   8.0    0s
# H 1332   401                     100.0000000  137.36409  37.4%   8.4    0s
# H 2368   171                     103.0000000  120.29416  16.8%   9.4    1s
#
# Cutting planes:
#   Cover: 6
#   MIR: 3
#   Inf proof: 2
#   Lazy constraints: 77
#
# Explored 2748 nodes (25917 simplex iterations) in 1.53 seconds (0.74 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 103 100 89 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 5998, time in user-callback 0.10 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x6bc68954
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 69 columns
# Presolve time: 0.05s
# Presolved: 59 rows, 831 columns, 2404 nonzeros
# Variable types: 0 continuous, 831 integer (831 binary)
#
# Root relaxation: objective 2.261728e+02, 102 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  226.17281    0    4   -0.00000  226.17281      -     -    0s
#      0     0  195.40163    0   24   -0.00000  195.40163      -     -    0s
#      0     0  193.11562    0   18   -0.00000  193.11562      -     -    0s
#      0     0  193.11562    0   26   -0.00000  193.11562      -     -    0s
#      0     0  187.01394    0   18   -0.00000  187.01394      -     -    0s
#      0     2  187.01394    0   18   -0.00000  187.01394      -     -    0s
# H  210   107                      78.0000000  163.61593   110%   7.3    0s
# H 1010   166                      90.0000000  124.21965  38.0%   7.8    0s
# H 1011   166                      94.0000000  122.26153  30.1%   7.8    0s
# H 1085   101                      98.0000000  116.50663  18.9%   7.7    0s
# H 1118   101                     103.0000000  116.10547  12.7%   7.7    0s
#
# Cutting planes:
#   Cover: 3
#   MIR: 1
#   Inf proof: 19
#   Lazy constraints: 65
#
# Explored 1278 nodes (9213 simplex iterations) in 0.85 seconds (0.37 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 103 98 94 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 3038, time in user-callback 0.08 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0x59ee8b44
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 48 columns
# Presolve time: 0.04s
# Presolved: 59 rows, 852 columns, 2466 nonzeros
# Variable types: 0 continuous, 852 integer (852 binary)
#
# Root relaxation: objective 2.152398e+02, 119 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  215.23984    0    4   -0.00000  215.23984      -     -    0s
#      0     0  160.22282    0   19   -0.00000  160.22282      -     -    0s
#      0     0  156.21550    0   25   -0.00000  156.21550      -     -    0s
#      0     0  150.71373    0   12   -0.00000  150.71373      -     -    0s
#      0     0  138.84174    0   33   -0.00000  138.84174      -     -    0s
# H    0     0                      41.0000000  138.84174   239%     -    0s
#      0     0  136.18558    0   32   41.00000  136.18558   232%     -    0s
#      0     2  135.40990    0   38   41.00000  135.40990   230%     -    0s
# H  369   174                      52.0000000  114.30945   120%   7.4    0s
# H  451   211                      90.0000000  114.30945  27.0%   7.4    0s
# H  502   216                      92.0000000  112.21064  22.0%   7.3    0s
# H  659   190                     103.0000000  108.11417  4.97%   7.3    0s
#
# Cutting planes:
#   Cover: 1
#   MIR: 3
#   Lazy constraints: 60
#
# Explored 851 nodes (5445 simplex iterations) in 0.64 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 103 92 90 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 2156, time in user-callback 0.08 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 57 rows, 841 columns and 2434 nonzeros
# Model fingerprint: 0x8db2cb1c
# Variable types: 0 continuous, 841 integer (841 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 77 columns
# Presolve time: 0.08s
# Presolved: 57 rows, 764 columns, 2209 nonzeros
# Variable types: 0 continuous, 764 integer (764 binary)
#
# Root relaxation: objective 2.330322e+02, 122 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  233.03218    0    4   -0.00000  233.03218      -     -    0s
# H    0     0                      40.0000000  233.03218   483%     -    0s
#      0     0  202.37072    0   18   40.00000  202.37072   406%     -    0s
#      0     0  202.37072    0   26   40.00000  202.37072   406%     -    0s
# H    0     0                      59.0000000  202.37072   243%     -    0s
#      0     0  199.47637    0   26   59.00000  199.47637   238%     -    0s
#      0     2  196.05891    0   26   59.00000  196.05891   232%     -    0s
# H  384   115                      80.0000000  155.08123  93.9%   7.5    0s
# H  469   116                      86.0000000  141.93239  65.0%   7.7    0s
# *  679    72              12     103.0000000  125.26546  21.6%   7.8    0s
#
# Cutting planes:
#   StrongCG: 1
#   Inf proof: 18
#   Lazy constraints: 57
#
# Explored 872 nodes (6305 simplex iterations) in 0.65 seconds (0.23 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 103 86 80 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 2109, time in user-callback 0.07 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59 rows, 900 columns and 2608 nonzeros
# Model fingerprint: 0xeace9cb0
# Variable types: 0 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 51 columns
# Presolve time: 0.04s
# Presolved: 59 rows, 849 columns, 2457 nonzeros
# Variable types: 0 continuous, 849 integer (849 binary)
#
# Root relaxation: objective 2.141988e+02, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  214.19878    0    4   -0.00000  214.19878      -     -    0s
#      0     0  159.22881    0   19   -0.00000  159.22881      -     -    0s
#      0     0  155.09755    0   25   -0.00000  155.09755      -     -    0s
#      0     0  155.09755    0   28   -0.00000  155.09755      -     -    0s
#      0     0  151.29565    0   19   -0.00000  151.29565      -     -    0s
# H    0     0                      25.0000000  151.29565   505%     -    0s
#      0     0  138.38063    0   16   25.00000  138.38063   454%     -    0s
#      0     0  138.38063    0   24   25.00000  138.38063   454%     -    0s
#      0     0  135.11872    0   22   25.00000  135.11872   440%     -    0s
#      0     2  132.61413    0   19   25.00000  132.61413   430%     -    0s
# H   41    41                      51.0000000  120.89293   137%   8.5    0s
# H   41    41                      52.0000000  120.89293   132%   8.5    0s
# H  308   156                      81.0000000  113.95859  40.7%   7.1    0s
# H  410   157                      82.0000000  112.60333  37.3%   7.0    0s
# H  420   157                      92.0000000  112.60333  22.4%   7.0    0s
# H  445   157                      93.0000000  111.40474  19.8%   7.3    0s
# H  485   157                      95.0000000  110.22257  16.0%   7.4    0s
# *  663     0              14      96.0000000   96.00000  0.00%   6.7    0s
#
# Cutting planes:
#   Cover: 2
#   MIR: 5
#   StrongCG: 1
#   Inf proof: 19
#   Lazy constraints: 51
#
# Explored 685 nodes (4605 simplex iterations) in 0.65 seconds (0.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 96 95 93 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.600000000000e+01, best bound 9.600000000000e+01, gap 0.0000%
#
# User-callback calls 1832, time in user-callback 0.07 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 55 rows, 784 columns and 2266 nonzeros
# Model fingerprint: 0x8bfd0082
# Variable types: 0 continuous, 784 integer (784 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 2e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 82 columns
# Presolve time: 0.04s
# Presolved: 55 rows, 702 columns, 2031 nonzeros
# Variable types: 0 continuous, 702 integer (702 binary)
#
# Root relaxation: objective 2.176958e+02, 107 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  217.69577    0    4   -0.00000  217.69577      -     -    0s
# H    0     0                      36.0000000  217.69577   505%     -    0s
#      0     0  182.16416    0   20   36.00000  182.16416   406%     -    0s
#      0     0  176.21039    0   20   36.00000  176.21039   389%     -    0s
#      0     2  176.21039    0   20   36.00000  176.21039   389%     -    0s
# *   32    31               7     103.0000000  164.65156  59.9%   8.1    0s
#
# Cutting planes:
#   Lazy constraints: 34
#
# Explored 423 nodes (2757 simplex iterations) in 0.41 seconds (0.12 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 103 36 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.030000000000e+02, best bound 1.030000000000e+02, gap 0.0000%
#
# User-callback calls 1186, time in user-callback 0.04 sec
#
# Processing instance: p4.2.b.txt
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 99 rows, 2500 columns and 7348 nonzeros
# Model fingerprint: 0x2f5c020e
# Variable types: 0 continuous, 2500 integer (2500 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 6 columns
# Presolve time: 0.03s
# Presolved: 99 rows, 2494 columns, 7328 nonzeros
# Variable types: 0 continuous, 2494 integer (2494 binary)
#
# Root relaxation: objective 3.490864e+02, 188 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  349.08638    0    4   -0.00000  349.08638      -     -    0s
#      0     0  293.82465    0   31   -0.00000  293.82465      -     -    0s
#      0     0  288.46979    0   31   -0.00000  288.46979      -     -    0s
#      0     2  288.46979    0   31   -0.00000  288.46979      -     -    0s
# H 1450   805                      38.0000000  257.73053   578%   8.1    2s
# H 1453   767                      47.0000000  241.89133   415%   8.1    3s
# H 1458   731                      77.0000000  236.76128   207%   8.0    3s
# H 1504   728                      78.0000000  233.12554   199%   8.9    4s
# H 1539   708                      98.0000000  232.51567   137%   9.1    4s
# H 1595   697                     101.0000000  232.51567   130%   9.5    4s
#   1827   763  226.79657   25   29  101.00000  228.61367   126%  10.4    5s
#   6455  2162  153.33555   41   21  101.00000  208.31569   106%  12.1   10s
#  12019  4042 infeasible   23       101.00000  200.31787  98.3%  12.8   15s
# H14825  4487                     124.0000000  197.25835  59.1%  12.8   17s
#  18890  5522  138.88110   26   45  124.00000  192.51871  55.3%  12.9   20s
# *26862  6710              39     125.0000000  185.50514  48.4%  12.9   24s
#  28930  6911     cutoff   40       125.00000  183.68687  46.9%  12.8   25s
# H29526  6874                     126.0000000  183.57594  45.7%  12.9   25s
#  36968  7451 infeasible   34       126.00000  177.96282  41.2%  12.8   30s
# *37240  7035              39     133.0000000  177.94348  33.8%  12.8   30s
#  44805  6823  157.80331   30   26  133.00000  171.88094  29.2%  12.7   35s
#  51672  6335  140.44854   27   30  133.00000  166.15707  24.9%  12.6   41s
# *55442  3544              46     147.0000000  163.34165  11.1%  12.6   43s
#  58875  1599     cutoff   52       147.00000  156.95397  6.77%  12.4   45s
# H59046   435                     152.0000000  156.95081  3.26%  12.4   45s
#
# Cutting planes:
#   Gomory: 25
#   Cover: 27
#   Clique: 10
#   StrongCG: 1
#   Flow cover: 1
#   Inf proof: 2
#   Zero half: 31
#   Lazy constraints: 303
#
# Explored 60260 nodes (737453 simplex iterations) in 46.24 seconds (19.22 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 152 147 133 ... 77
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.520000000000e+02, best bound 1.520000000000e+02, gap 0.0000%
#
# User-callback calls 124378, time in user-callback 2.02 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 99 rows, 2500 columns and 7348 nonzeros
# Model fingerprint: 0x8e93642a
# Variable types: 0 continuous, 2500 integer (2500 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 4 columns
# Presolve time: 0.02s
# Presolved: 99 rows, 2496 columns, 7334 nonzeros
# Variable types: 0 continuous, 2496 integer (2496 binary)
#
# Root relaxation: objective 3.167065e+02, 162 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  316.70652    0    4   -0.00000  316.70652      -     -    0s
#      0     0  276.49249    0   30   -0.00000  276.49249      -     -    0s
#      0     0  273.36264    0   21   -0.00000  273.36264      -     -    0s
#      0     0  253.25199    0   24   -0.00000  253.25199      -     -    0s
#      0     2  251.38766    0   24   -0.00000  251.38766      -     -    0s
# H 1576   832                      32.0000000  229.16712   616%  10.1    3s
# H 1577   790                      36.0000000  229.16712   537%  10.1    3s
# H 1579   752                      66.0000000  229.16712   247%  10.1    3s
# H 1585   718                      84.0000000  221.00127   163%  10.0    3s
# H 1598   690                     139.0000000  210.62733  51.5%  10.0    5s
# H 1602   659                     150.0000000  204.65875  36.4%  10.4    5s
# H 2188   715                     156.0000000  203.18980  30.2%  12.5    7s
# H 5296   389                     159.0000000  178.26040  12.1%  13.2    9s
# * 6220     0              51     160.0000000  168.58163  5.36%  13.3    9s
#
# Cutting planes:
#   Gomory: 17
#   Cover: 11
#   Clique: 7
#   StrongCG: 1
#   Flow cover: 4
#   Inf proof: 6
#   Zero half: 36
#   Mod-K: 2
#   Lazy constraints: 8
#
# Explored 6284 nodes (83472 simplex iterations) in 9.36 seconds (4.17 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 160 159 156 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.600000000000e+02, best bound 1.600000000000e+02, gap 0.0000%
#
# User-callback calls 15283, time in user-callback 0.44 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 95 rows, 2304 columns and 6766 nonzeros
# Model fingerprint: 0x706d30ed
# Variable types: 0 continuous, 2304 integer (2304 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 28 columns
# Presolve time: 0.06s
# Presolved: 95 rows, 2276 columns, 6680 nonzeros
# Variable types: 0 continuous, 2276 integer (2276 binary)
#
# Root relaxation: objective 3.204979e+02, 155 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  320.49794    0    4   -0.00000  320.49794      -     -    0s
#      0     0  238.74164    0   35   -0.00000  238.74164      -     -    0s
#      0     0  235.62037    0   29   -0.00000  235.62037      -     -    0s
#      0     0  234.89906    0   29   -0.00000  234.89906      -     -    0s
#      0     0  230.62280    0   29   -0.00000  230.62280      -     -    0s
#      0     2  230.62280    0   29   -0.00000  230.62280      -     -    0s
# H 1279   655                     103.0000000  196.80286  91.1%   8.5    1s
# H 1340   661                     113.0000000  196.80286  74.2%   8.4    1s
# H 1382   679                     114.0000000  195.23021  71.3%   8.3    1s
# H 1441   643                     128.0000000  195.07369  52.4%   8.3    1s
# H 1443   596                     135.0000000  195.07369  44.5%   8.3    1s
# H 1784   675                     141.0000000  178.75734  26.8%   8.7    2s
# * 1912   645              37     142.0000000  178.70806  25.9%   8.8    2s
# H 1960   607                     168.0000000  178.29137  6.13%   8.9    3s
#
# Cutting planes:
#   Gomory: 34
#   Cover: 2
#   Clique: 5
#   MIR: 1
#   Zero half: 15
#   Lazy constraints: 4
#
# Explored 2274 nodes (19855 simplex iterations) in 3.33 seconds (1.58 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 168 142 141 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.680000000000e+02, best bound 1.680000000000e+02, gap 0.0000%
#
# User-callback calls 5552, time in user-callback 0.39 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 99 rows, 2500 columns and 7348 nonzeros
# Model fingerprint: 0xda1d5536
# Variable types: 0 continuous, 2500 integer (2500 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 30 columns
# Presolve time: 0.07s
# Presolved: 99 rows, 2470 columns, 7256 nonzeros
# Variable types: 0 continuous, 2470 integer (2470 binary)
#
# Root relaxation: objective 3.178447e+02, 142 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  317.84473    0    4   -0.00000  317.84473      -     -    0s
#      0     0  277.65703    0   30   -0.00000  277.65703      -     -    0s
#      0     0  274.45908    0   21   -0.00000  274.45908      -     -    0s
#      0     0  254.45251    0   24   -0.00000  254.45251      -     -    0s
#      0     2  252.58818    0   24   -0.00000  252.58818      -     -    0s
# H 1238   711                      87.0000000  232.14907   167%  10.0    1s
# H 1247   710                      93.0000000  232.14907   150%   9.9    1s
# H 1557   822                     156.0000000  215.79173  38.3%  10.5    4s
# H 2759   738                     160.0000000  195.57424  22.2%  10.9    4s
#   3072   730     cutoff   22       160.00000  193.70561  21.1%  10.9    5s
# H 3412   595                     163.0000000  191.91127  17.7%  10.7    5s
#
# Cutting planes:
#   Gomory: 12
#   Cover: 18
#   Clique: 5
#   MIR: 2
#   Flow cover: 3
#   Inf proof: 3
#   Zero half: 32
#   Lazy constraints: 13
#
# Explored 6598 nodes (73331 simplex iterations) in 6.25 seconds (2.98 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 163 160 156 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.630000000000e+02, best bound 1.630000000000e+02, gap 0.0000%
#
# User-callback calls 14674, time in user-callback 0.35 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 93 rows, 2209 columns and 6484 nonzeros
# Model fingerprint: 0x4679ec85
# Variable types: 0 continuous, 2209 integer (2209 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 48 columns
# Presolve time: 0.08s
# Presolved: 93 rows, 2161 columns, 6338 nonzeros
# Variable types: 0 continuous, 2161 integer (2161 binary)
#
# Root relaxation: objective 3.317544e+02, 156 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  331.75438    0    4   -0.00000  331.75438      -     -    0s
# H    0     0                      78.0000000  331.75438   325%     -    0s
#      0     0  277.08158    0   31   78.00000  277.08158   255%     -    0s
#      0     0  277.08158    0   33   78.00000  277.08158   255%     -    0s
#      0     0  276.43084    0   33   78.00000  276.43084   254%     -    0s
#      0     2  273.99052    0   33   78.00000  273.99052   251%     -    0s
# H 1472   677                      79.0000000  243.90379   209%  11.0    2s
# H 1703   740                      96.0000000  229.86449   139%  10.8    3s
#   1718   750  217.59314   11   49   96.00000  222.02266   131%  10.7    5s
# H 1795   760                      98.0000000  219.82551   124%  11.9    6s
# H 1842   728                     109.0000000  219.82551   102%  12.1    6s
# * 2074   716              36     120.0000000  219.07718  82.6%  12.4    6s
# H 2271   705                     127.0000000  214.24494  68.7%  12.7    7s
# H 2273   674                     135.0000000  214.24494  58.7%  12.7    7s
# H 2275   643                     142.0000000  214.24494  50.9%  12.7    7s
# H 3876   844                     145.0000000  198.75115  37.1%  12.7    8s
# H 3877   778                     153.0000000  198.75115  29.9%  12.7    8s
# H 4154   784                     154.0000000  197.75828  28.4%  12.7    8s
# H 4496   778                     156.0000000  196.49236  26.0%  12.8    8s
#   5780   930  171.78406   27   23  156.00000  189.72169  21.6%  13.1   10s
# H 6081   935                     158.0000000  188.98081  19.6%  13.1   10s
# H 9204  1012                     159.0000000  178.68721  12.4%  12.9   13s
# H 9303   643                     167.0000000  178.58503  6.94%  12.9   13s
# * 9948   141              28     168.0000000  175.96684  4.74%  12.6   13s
#
# Cutting planes:
#   Gomory: 24
#   Cover: 7
#   Clique: 4
#   Flow cover: 2
#   Inf proof: 2
#   Zero half: 61
#   Lazy constraints: 147
#
# Explored 10613 nodes (130211 simplex iterations) in 13.80 seconds (6.00 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 168 167 159 ... 135
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.680000000000e+02, best bound 1.680000000000e+02, gap 0.0000%
#
# User-callback calls 24024, time in user-callback 1.09 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 95 rows, 2304 columns and 6766 nonzeros
# Model fingerprint: 0x5749e65a
# Variable types: 0 continuous, 2304 integer (2304 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 59 columns
# Presolve time: 0.07s
# Presolved: 95 rows, 2245 columns, 6587 nonzeros
# Variable types: 0 continuous, 2245 integer (2245 binary)
#
# Root relaxation: objective 3.225205e+02, 169 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  322.52051    0    4   -0.00000  322.52051      -     -    0s
#      0     0  257.87749    0   30   -0.00000  257.87749      -     -    0s
#      0     0  251.44468    0   30   -0.00000  251.44468      -     -    0s
#      0     0  245.23597    0   30   -0.00000  245.23597      -     -    0s
#      0     2  245.01299    0   30   -0.00000  245.01299      -     -    0s
# *  885   448              19      77.0000000  210.40601   173%   9.2    1s
# * 1127   564              50     113.0000000  209.05368  85.0%   8.7    1s
# H 1285   400                     147.0000000  207.04348  40.8%   8.6    1s
# H 1926   575                     148.0000000  204.18950  38.0%   8.9    2s
# H 1941   556                     156.0000000  193.00883  23.7%   8.8    2s
# * 2375   515              54     159.0000000  173.29865  8.99%   9.9    3s
#
# Cutting planes:
#   Gomory: 7
#   Cover: 4
#   Clique: 4
#   MIR: 1
#   Flow cover: 3
#   Zero half: 33
#   Lazy constraints: 4
#
# Explored 2784 nodes (28151 simplex iterations) in 3.73 seconds (1.82 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 159 156 148 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.590000000000e+02, best bound 1.590000000000e+02, gap 0.0000%
#
# User-callback calls 6827, time in user-callback 0.28 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 93 rows, 2209 columns and 6484 nonzeros
# Model fingerprint: 0xf1383a02
# Variable types: 0 continuous, 2209 integer (2209 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 51 columns
# Presolve time: 0.08s
# Presolved: 93 rows, 2158 columns, 6329 nonzeros
# Variable types: 0 continuous, 2158 integer (2158 binary)
#
# Root relaxation: objective 3.308871e+02, 165 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  330.88711    0    4   -0.00000  330.88711      -     -    0s
#      0     0  275.18379    0   39   -0.00000  275.18379      -     -    0s
#      0     0  274.34184    0   40   -0.00000  274.34184      -     -    0s
#      0     0  272.41621    0   40   -0.00000  272.41621      -     -    0s
#      0     2  272.41621    0   40   -0.00000  272.41621      -     -    0s
# H  951   406                      94.0000000  243.55664   159%  10.8    1s
# H 1886   673                     121.0000000  237.53678  96.3%  11.0    3s
# H 1893   644                     150.0000000  234.75286  56.5%  11.0    3s
# H 1901   617                     153.0000000  228.56832  49.4%  11.2    3s
#   2091   690  179.47139   40   13  153.00000  217.43983  42.1%  12.5    5s
# * 6619  1075              46     154.0000000  184.16368  19.6%  12.5    7s
# H 7011   728                     166.0000000  182.68115  10.0%  12.5    8s
# H 7019   688                     167.0000000  182.68115  9.39%  12.5    8s
# H 7526   529                     168.0000000  179.90494  7.09%  12.3    9s
#
# Cutting planes:
#   Gomory: 34
#   Clique: 2
#   MIR: 2
#   Flow cover: 3
#   Inf proof: 3
#   Zero half: 26
#   Lazy constraints: 116
#
# Explored 8547 nodes (100865 simplex iterations) in 9.94 seconds (4.07 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 9: 168 167 166 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.680000000000e+02, best bound 1.680000000000e+02, gap 0.0000%
#
# User-callback calls 19050, time in user-callback 0.89 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 95 rows, 2304 columns and 6766 nonzeros
# Model fingerprint: 0x90df89e3
# Variable types: 0 continuous, 2304 integer (2304 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 28 columns
# Presolve time: 0.06s
# Presolved: 95 rows, 2276 columns, 6680 nonzeros
# Variable types: 0 continuous, 2276 integer (2276 binary)
#
# Root relaxation: objective 3.056374e+02, 157 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  305.63740    0    4   -0.00000  305.63740      -     -    0s
#      0     0  253.16278    0   26   -0.00000  253.16278      -     -    0s
#      0     0  252.35375    0   19   -0.00000  252.35375      -     -    0s
#      0     0  252.35375    0   25   -0.00000  252.35375      -     -    0s
#      0     0  249.25613    0   25   -0.00000  249.25613      -     -    0s
#      0     2  246.21314    0   25   -0.00000  246.21314      -     -    0s
# *  257   168              14     159.0000000  233.65786  47.0%   8.9    0s
# H 1377   414                     163.0000000  207.28562  27.2%   8.5    1s
# H 2041   351                     172.0000000  197.97254  15.1%   8.8    1s
# H 2276   287                     173.0000000  195.16231  12.8%   9.2    1s
#
# Cutting planes:
#   Cover: 12
#   MIR: 1
#   StrongCG: 1
#   Inf proof: 5
#   Lazy constraints: 57
#
# Explored 2839 nodes (26464 simplex iterations) in 1.99 seconds (1.21 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 173 172 163 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.730000000000e+02, best bound 1.730000000000e+02, gap 0.0000%
#
# User-callback calls 6273, time in user-callback 0.13 sec
#
# Processing instance: p4.2.c.txt
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 135 rows, 4624 columns and 13666 nonzeros
# Model fingerprint: 0xd837b3aa
# Variable types: 0 continuous, 4624 integer (4624 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve time: 0.03s
# Presolved: 135 rows, 4624 columns, 13664 nonzeros
# Variable types: 0 continuous, 4624 integer (4624 binary)
#
# Root relaxation: objective 4.658284e+02, 234 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  465.82839    0    4   -0.00000  465.82839      -     -    0s
#      0     0  339.15223    0   64   -0.00000  339.15223      -     -    1s
#      0     0  331.99762    0   62   -0.00000  331.99762      -     -    1s
#      0     0  327.85016    0   57   -0.00000  327.85016      -     -    1s
#      0     0  322.74837    0   51   -0.00000  322.74837      -     -    1s
#      0     2  322.74837    0   51   -0.00000  322.74837      -     -    1s
#   1322   907  262.54066   14   51   -0.00000  303.41916      -   9.6    5s
# H 1341   873                      37.0000000  274.02356   641%   9.4    9s
#   1345   875  202.56745   25   93   37.00000  272.58119   637%   9.4   11s
#   2153  1137  245.93399   32   32   37.00000  271.01660   632%  14.6   15s
# H 3027  1419                      82.0000000  270.63645   230%  13.3   17s
# H 4087  1780                     101.0000000  262.06749   159%  13.5   18s
#   5248  2520  229.82955   23   28  101.00000  259.80596   157%  14.0   20s
# H 5619  2676                     107.0000000  259.13722   142%  14.2   20s
#   7768  3804     cutoff   36       107.00000  256.60034   140%  15.2   25s
#  10500  5507 infeasible   29       107.00000  254.16328   138%  15.5   30s
# H12242  6168                     112.0000000  253.30317   126%  15.4   33s
#  12825  6599  191.17591   35   65  112.00000  252.46070   125%  15.5   35s
#  13703  6968  251.45611   26   49  112.00000  251.72451   125%  15.6   40s
#  15985  8086  212.63061   34   51  112.00000  250.13931   123%  16.0   45s
#  18114  9120  193.84560   43   50  112.00000  248.61950   122%  16.1   50s
# *18280  9086              78     120.0000000  248.60457   107%  16.1   50s
# *18282  9077              79     121.0000000  248.60457   105%  16.1   50s
# *18288  8982              81     131.0000000  248.60457  89.8%  16.1   50s
#  20759 10372  174.62293   34   20  131.00000  247.32097  88.8%  16.1   57s
#  22823 11520  183.05001  111   11  131.00000  246.43814  88.1%  16.1   60s
#  26115 12963     cutoff   35       131.00000  245.39588  87.3%  15.9   67s
#  28697 13959     cutoff   32       131.00000  244.55967  86.7%  16.0   70s
#  31943 14882  179.36805   44   27  131.00000  243.33992  85.8%  16.1   76s
#  33120 15807  176.92157   30   21  131.00000  242.99499  85.5%  16.1   80s
#  35266 16684  192.81573   31   43  131.00000  242.43369  85.1%  16.1   85s
# H35382 13779                     172.0000000  242.43369  40.9%  16.2   85s
# H36288 12991                     176.0000000  242.09442  37.6%  16.2   88s
#  36295 13305  190.55613   32   45  176.00000  242.08413  37.5%  16.2   91s
#  39989 14365  232.36957   19   59  176.00000  240.92453  36.9%  16.1   96s
#  43528 15183  190.19881   29   51  176.00000  239.86740  36.3%  16.0  110s
#  43781 15309  239.86740   29   95  176.00000  239.86740  36.3%  16.1  115s
# H44014 14549                     210.0000000  239.86740  14.2%  16.1  118s
#  44732 14493  217.93020   36   51  210.00000  239.86740  14.2%  16.1  120s
# H44823 13740                     216.0000000  239.86740  11.0%  16.1  120s
#  47592 13140     cutoff   37       216.00000  238.86960  10.6%  15.9  125s
#
# Cutting planes:
#   Gomory: 41
#   Cover: 15
#   Clique: 10
#   MIR: 10
#   Flow cover: 5
#   Inf proof: 4
#   Zero half: 80
#   Lazy constraints: 4
#
# Explored 51352 nodes (814248 simplex iterations) in 129.55 seconds (46.97 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 216 210 176 ... 101
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.160000000000e+02, best bound 2.160000000000e+02, gap 0.0000%
#
# User-callback calls 113294, time in user-callback 7.70 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 133 rows, 4489 columns and 13264 nonzeros
# Model fingerprint: 0x22c69a03
# Variable types: 0 continuous, 4489 integer (4489 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 2 columns
# Presolve time: 0.04s
# Presolved: 133 rows, 4487 columns, 13256 nonzeros
# Variable types: 0 continuous, 4487 integer (4487 binary)
#
# Root relaxation: objective 4.430852e+02, 210 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  443.08521    0    4   -0.00000  443.08521      -     -    0s
#      0     0  356.20987    0   40   -0.00000  356.20987      -     -    0s
#      0     0  352.54338    0   32   -0.00000  352.54338      -     -    0s
#      0     0  338.05508    0   36   -0.00000  338.05508      -     -    0s
#      0     0  338.05508    0   42   -0.00000  338.05508      -     -    0s
#      0     0  324.65179    0   66   -0.00000  324.65179      -     -    0s
#      0     2  298.50137    0   69   -0.00000  298.50137      -     -    0s
#   1365   900  277.82740   10   63   -0.00000  297.93938      -   9.4    5s
# H 1365   854                     237.0000000  297.93938  25.7%   9.4    6s
# H 1447   857                     238.0000000  255.79362  7.48%  11.0    7s
# H 1788   682                     241.0000000  241.53935  0.22%  11.8    8s
#
# Cutting planes:
#   Gomory: 16
#   Clique: 7
#   MIR: 3
#   Flow cover: 3
#   Zero half: 24
#
# Explored 1803 nodes (21591 simplex iterations) in 8.20 seconds (3.84 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 241 238 237 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.410000000000e+02, best bound 2.410000000000e+02, gap 0.0000%
#
# User-callback calls 5819, time in user-callback 0.67 sec
# WARNING:root:No optimal solution found for SPP.
# WARNING:root:No best solution found. Returning a trivial empty solution to avoid None.
# Processing instance: p4.2.d.txt
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 161 rows, 6561 columns and 19438 nonzeros
# Model fingerprint: 0x1065f046
# Variable types: 0 continuous, 6561 integer (6561 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 3e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 4e+01]
# Found heuristic solution: objective -0.0000000
# Presolve time: 0.05s
# Presolved: 161 rows, 6561 columns, 19436 nonzeros
# Variable types: 0 continuous, 6561 integer (6561 binary)
#
# Root relaxation: objective 4.898902e+02, 284 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  489.89016    0    4   -0.00000  489.89016      -     -    0s
#      0     0  369.34085    0   53   -0.00000  369.34085      -     -    0s
#      0     2  367.90504    0   53   -0.00000  367.90504      -     -    0s
#   1209   934  294.86934   21   53   -0.00000  346.56637      -  10.2    5s
# H 1210   888                      24.0000000  346.56637  1344%  10.2    6s
# H 1210   843                      95.0000000  346.56637   265%  10.2    6s
# H 1217   805                      97.0000000  303.61978   213%  10.1    9s
#   1218   806  216.69339   25  110   97.00000  303.61978   213%  10.1   10s
#   2162  1211  289.59066   21   52   97.00000  297.45749   207%  14.9   15s
#   3809  1886  290.40991   26   80   97.00000  294.81867   204%  15.4   20s
# H 4601  2302                     157.0000000  293.88768  87.2%  15.1   23s
#   5495  2927     cutoff   35       157.00000  292.91697  86.6%  15.6   25s
#   7469  4040  260.92086   22   50  157.00000  291.26064  85.5%  16.1   30s
#   9305  5126  267.11603   26   37  157.00000  289.90341  84.7%  16.8   35s
# H10030  4812                     196.0000000  289.68701  47.8%  17.0   37s
# H10396  4739                     207.0000000  289.45714  39.8%  17.0   39s
#  10610  5060  264.47115   28   51  207.00000  289.21569  39.7%  17.0   40s
#  13154  6125     cutoff   34       207.00000  287.87131  39.1%  17.4   45s
#  14450  6699     cutoff   28       207.00000  287.28836  38.8%  17.5   50s
#  16166  7417  256.98066   35   36  207.00000  286.48881  38.4%  17.6   55s
#  17822  8119  277.59219   29   61  207.00000  285.89569  38.1%  17.7   60s
#  20794  9280  281.38919   27   43  207.00000  285.04795  37.7%  17.7   65s
#  22873 10149  233.90370   34   29  207.00000  284.32522  37.4%  17.7   70s
#  25155 11057 infeasible   49       207.00000  283.66711  37.0%  17.7   75s
#  27946 11992  271.68680   27   34  207.00000  282.86357  36.6%  17.8   80s
#  29384 12406  260.36236   27   54  207.00000  282.57419  36.5%  17.8   85s
#  30688 12908  257.41292   34   29  207.00000  282.23597  36.3%  17.9   90s
#  31907 13370  280.74762   30   59  207.00000  281.97660  36.2%  17.9   95s
#  33426 13971  263.08263   26   50  207.00000  281.64325  36.1%  18.0  100s
#  33945 13972  262.64700   34   53  207.00000  281.55404  36.0%  18.0  110s
#  33969 13991  281.55404   26   98  207.00000  281.55404  36.0%  18.1  115s
#  34072 14070  274.95307   34   71  207.00000  281.55404  36.0%  18.1  120s
#  34566 14237  277.29352   47   82  207.00000  281.55404  36.0%  18.2  125s
#  35982 14467  272.77074   49   70  207.00000  281.55404  36.0%  18.3  131s
#  37675 14812  260.87532   39   64  207.00000  281.55404  36.0%  18.5  136s
#  39828 14964  269.97070   43   69  207.00000  281.55404  36.0%  18.6  142s
# H40793 14001                     220.0000000  281.55404  28.0%  18.6  143s
# H40797 13158                     228.0000000  281.55404  23.5%  18.6  143s
# H41460 12533                     231.0000000  281.34176  21.8%  18.6  146s
#  44195 12563  272.91914   36   50  231.00000  278.80550  20.7%  18.6  150s
#  46586 12397  237.11563   47   46  231.00000  276.76444  19.8%  18.7  155s
#  49010 12650  247.35136   79   49  231.00000  275.55239  19.3%  18.7  160s
# H52042 11629                     233.0000000  274.51408  17.8%  18.7  164s
# *52049 10986              62     234.0000000  274.51408  17.3%  18.7  164s
#  52236 11222  246.45981   96   26  234.00000  274.27707  17.2%  18.6  165s
#  54694 11062  254.31080   49   44  234.00000  273.10049  16.7%  18.6  170s
# H56040  6827                     256.0000000  272.60440  6.49%  18.6  173s
#  56694  6483     cutoff   39       256.00000  272.42758  6.42%  18.6  175s
#  60624  5041     cutoff   46       256.00000  269.57345  5.30%  18.5  180s
#  63938  3403  260.79432   41   54  256.00000  267.16131  4.36%  18.4  186s
#  66861  2272     cutoff   46       256.00000  264.71008  3.40%  18.2  190s
#  71170     0     cutoff   43       256.00000  257.81264  0.71%  17.9  195s
#
# Cutting planes:
#   Gomory: 38
#   Cover: 28
#   Clique: 11
#   MIR: 1
#   Flow cover: 7
#   Inf proof: 3
#   Zero half: 101
#   Lazy constraints: 84
#
# Explored 71423 nodes (1273116 simplex iterations) in 195.22 seconds (80.98 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 256 234 233 ... 97
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.560000000000e+02, best bound 2.560000000000e+02, gap 0.0000%
#
# ...
#      0     0  359.34150    0   24   -0.00000  359.34150      -     -    0s
#      0     2  359.34150    0   24   -0.00000  359.34150      -     -    0s
# *   32    38               7     351.0000000  353.79379  0.80%   8.4    0s
#
# Cutting planes:
#   Lazy constraints: 40
#
# Explored 71 nodes (534 simplex iterations) in 0.56 seconds (0.13 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 351 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.510000000000e+02, best bound 3.510000000000e+02, gap 0.0000%
#
# User-callback calls 506, time in user-callback 0.07 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 63 rows, 1024 columns and 2974 nonzeros
# Model fingerprint: 0xd39b656a
# Variable types: 0 continuous, 1024 integer (1024 binary)
# Coefficient statistics:
#   Matrix range     [7e-01, 4e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 63 rows, 1023 columns, 2969 nonzeros
# Variable types: 0 continuous, 1023 integer (1023 binary)
#
# Root relaxation: objective 2.808133e+02, 147 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  280.81332    0    4   -0.00000  280.81332      -     -    0s
#      0     0  244.59912    0   19   -0.00000  244.59912      -     -    0s
#      0     0  242.55755    0   31   -0.00000  242.55755      -     -    0s
#      0     0  241.25548    0   16   -0.00000  241.25548      -     -    0s
#      0     0  240.86381    0   15   -0.00000  240.86381      -     -    0s
# H    0     0                     137.0000000  240.86381  75.8%     -    0s
#      0     0  238.19821    0   30  137.00000  238.19821  73.9%     -    0s
# H    0     0                     200.0000000  237.65253  18.8%     -    0s
#      0     0  237.58968    0   28  200.00000  237.58968  18.8%     -    0s
#      0     0  234.62341    0   56  200.00000  234.62341  17.3%     -    0s
#      0     0  233.11668    0   17  200.00000  233.11668  16.6%     -    0s
# H    0     0                     231.0000000  233.11668  0.92%     -    0s
#      0     0  233.11388    0   29  231.00000  233.11388  0.92%     -    0s
#      0     0  233.11388    0    7  231.00000  233.11388  0.92%     -    0s
# H    0     0                     232.0000000  233.11388  0.48%     -    0s
# H    0     0                     233.0000000  233.11388  0.05%     -    0s
#      0     0  233.11388    0    7  233.00000  233.11388  0.05%     -    0s
#
# Cutting planes:
#   Lazy constraints: 1
#
# Explored 1 nodes (431 simplex iterations) in 0.48 seconds (0.08 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 7: 233 232 231 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.330000000000e+02, best bound 2.330000000000e+02, gap 0.0000%
#
# User-callback calls 405, time in user-callback 0.07 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 65 rows, 1089 columns and 3166 nonzeros
# Model fingerprint: 0x3188623d
# Variable types: 0 continuous, 1089 integer (1089 binary)
# Coefficient statistics:
#   Matrix range     [4e-01, 4e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective -0.0000000
# Presolve time: 0.01s
# Presolved: 65 rows, 1089 columns, 3164 nonzeros
# Variable types: 0 continuous, 1089 integer (1089 binary)
#
# Root relaxation: objective 3.592530e+02, 127 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  359.25304    0    4   -0.00000  359.25304      -     -    0s
# H    0     0                      77.0000000  359.25304   367%     -    0s
#      0     0  328.63609    0    7   77.00000  328.63609   327%     -    0s
#      0     0  306.77231    0   26   77.00000  306.77231   298%     -    0s
# H    0     0                     152.0000000  306.77231   102%     -    0s
#      0     0  304.11028    0   34  152.00000  304.11028   100%     -    0s
#      0     0  302.75011    0   46  152.00000  302.75011  99.2%     -    0s
# H    0     0                     167.0000000  302.75011  81.3%     -    0s
#      0     0  300.32295    0   54  167.00000  300.32295  79.8%     -    0s
#      0     0  300.32295    0   57  167.00000  300.32295  79.8%     -    0s
#      0     0  299.41468    0   54  167.00000  299.41468  79.3%     -    0s
# H    0     0                     185.0000000  299.41468  61.8%     -    0s
#      0     2  299.41468    0   54  185.00000  299.41468  61.8%     -    0s
# H  121   106                     210.0000000  294.40220  40.2%   7.9    0s
# H  122   106                     214.0000000  294.40220  37.6%   7.9    0s
# H  169   144                     275.0000000  294.40220  7.06%   8.0    0s
#
# Cutting planes:
#   MIR: 2
#   Inf proof: 2
#   Lazy constraints: 45
#
# Explored 403 nodes (2776 simplex iterations) in 0.51 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 8: 275 214 210 ... -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.750000000000e+02, best bound 2.750000000000e+02, gap 0.0000%
#
# User-callback calls 1125, time in user-callback 0.07 sec
# Set parameter LazyConstraints to value 1
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: Intel(R) Core(TM) i5-9300HF CPU @ 2.40GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 83 rows, 1764 columns and 5164 nonzeros
# Model fingerprint: 0x31036735
# Variable types: 0 continuous, 1764 integer (1764 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 3e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 6e+01]
# Found heuristic solution: objective -0.0000000
# Presolve time: 0.02s
# Presolved: 83 rows, 1764 columns, 5162 nonzeros
# Variable types: 0 continuous, 1764 integer (1764 binary)
#
# Root relaxation: objective 4.234835e+02, 167 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  423.48352    0    4   -0.00000  423.48352      -     -    0s
#      0     0  367.61391    0   60   -0.00000  367.61391      -     -    0s
#      0     0  367.43401    0   55   -0.00000  367.43401      -     -    0s
#      0     0  363.09541    0   53   -0.00000  363.09541      -     -    0s
#      0     2  363.09541    0   53   -0.00000  363.09541      -     -    0s
# *    4     6               2     361.0000000  361.00000  0.00%  10.0    0s
#
# Cutting planes:
#   MIR: 1
#   Lazy constraints: 27
#
# Explored 7 nodes (300 simplex iterations) in 0.30 seconds (0.09 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 361 -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.610000000000e+02, best bound 3.610000000000e+02, gap 0.0000%
#
# User-callback calls 249, time in user-callback 0.05 sec
# WARNING:root:No optimal solution found for SPP.
# WARNING:root:No best solution found. Returning a trivial empty solution to avoid None.
# {'Instance': 'p4.2.a.txt', 'RunTime': 6.896641492843628, 'Gap': 0.0, 'TotalCollectedPrize': 206.0, 'AveragePrizePerVehicle': 103.0}
# {'Instance': 'p4.2.b.txt', 'RunTime': 101.57292461395264, 'Gap': 0.0, 'TotalCollectedPrize': 341.0, 'AveragePrizePerVehicle': 170.5}
# {'Instance': 'p4.2.c.txt', 'RunTime': 147.65275359153748, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.2.d.txt', 'RunTime': 223.83649730682373, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.2.e.txt', 'RunTime': 233.86602401733398, 'Gap': 0.0, 'TotalCollectedPrize': 606.0, 'AveragePrizePerVehicle': 303.0}
# {'Instance': 'p4.2.f.txt', 'RunTime': 677.1125829219818, 'Gap': 0.0, 'TotalCollectedPrize': 669.0, 'AveragePrizePerVehicle': 334.5}
# {'Instance': 'p4.2.g.txt', 'RunTime': 133.95486879348755, 'Gap': 0.0, 'TotalCollectedPrize': 719.0, 'AveragePrizePerVehicle': 359.5}
# {'Instance': 'p4.2.h.txt', 'RunTime': 198.19384932518005, 'Gap': 0.0, 'TotalCollectedPrize': 792.0, 'AveragePrizePerVehicle': 396.0}
# {'Instance': 'p4.2.i.txt', 'RunTime': 165.50545358657837, 'Gap': 0.0, 'TotalCollectedPrize': 852.0, 'AveragePrizePerVehicle': 426.0}
# {'Instance': 'p4.2.j.txt', 'RunTime': 137.54537320137024, 'Gap': 0.0, 'TotalCollectedPrize': 881.0, 'AveragePrizePerVehicle': 440.5}
# {'Instance': 'p4.2.k.txt', 'RunTime': 101.26913523674011, 'Gap': 0.0, 'TotalCollectedPrize': 993.0, 'AveragePrizePerVehicle': 496.5}
# {'Instance': 'p4.2.l.txt', 'RunTime': 190.64478087425232, 'Gap': 0.0, 'TotalCollectedPrize': 1032.0, 'AveragePrizePerVehicle': 516.0}
# {'Instance': 'p4.2.m.txt', 'RunTime': 243.12051129341125, 'Gap': 0.0, 'TotalCollectedPrize': 1110.0, 'AveragePrizePerVehicle': 555.0}
# {'Instance': 'p4.2.n.txt', 'RunTime': 187.41998553276062, 'Gap': 0.0, 'TotalCollectedPrize': 1103.0, 'AveragePrizePerVehicle': 551.5}
# {'Instance': 'p4.2.o.txt', 'RunTime': 143.4561276435852, 'Gap': 0.0, 'TotalCollectedPrize': 1141.0, 'AveragePrizePerVehicle': 570.5}
# {'Instance': 'p4.2.p.txt', 'RunTime': 89.21361470222473, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.2.q.txt', 'RunTime': 74.10076594352722, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.2.r.txt', 'RunTime': 79.86582398414612, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.2.s.txt', 'RunTime': 136.42811274528503, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.2.t.txt', 'RunTime': 161.26935577392578, 'Gap': 0.0, 'TotalCollectedPrize': 1294.0, 'AveragePrizePerVehicle': 647.0}
# {'Instance': 'p4.3.a.txt', 'RunTime': 0.1530904769897461, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.3.b.txt', 'RunTime': 0.19753336906433105, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.3.c.txt', 'RunTime': 2.7605700492858887, 'Gap': 0.0, 'TotalCollectedPrize': 193.0, 'AveragePrizePerVehicle': 64.33333333333333}
# {'Instance': 'p4.3.d.txt', 'RunTime': 29.97530770301819, 'Gap': 0.0, 'TotalCollectedPrize': 332.0, 'AveragePrizePerVehicle': 110.66666666666667}
# {'Instance': 'p4.3.e.txt', 'RunTime': 44.60469388961792, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.3.f.txt', 'RunTime': 91.5925817489624, 'Gap': 0.0, 'TotalCollectedPrize': 524.0, 'AveragePrizePerVehicle': 174.66666666666666}
# {'Instance': 'p4.3.g.txt', 'RunTime': 357.5278081893921, 'Gap': 0.0, 'TotalCollectedPrize': 625.0, 'AveragePrizePerVehicle': 208.33333333333334}
# {'Instance': 'p4.3.h.txt', 'RunTime': 230.18288350105286, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.3.i.txt', 'RunTime': 73.77810215950012, 'Gap': 0.0, 'TotalCollectedPrize': 719.0, 'AveragePrizePerVehicle': 239.66666666666666}
# {'Instance': 'p4.3.j.txt', 'RunTime': 376.24312448501587, 'Gap': 0.0, 'TotalCollectedPrize': 833.0, 'AveragePrizePerVehicle': 277.6666666666667}
# {'Instance': 'p4.3.k.txt', 'RunTime': 661.1423668861389, 'Gap': 0.0, 'TotalCollectedPrize': 914.0, 'AveragePrizePerVehicle': 304.6666666666667}
# {'Instance': 'p4.3.l.txt', 'RunTime': 92.32385325431824, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.3.m.txt', 'RunTime': 118.65555143356323, 'Gap': 0.0, 'TotalCollectedPrize': 1008.0, 'AveragePrizePerVehicle': 336.0}
# {'Instance': 'p4.3.n.txt', 'RunTime': 211.5790295600891, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.3.o.txt', 'RunTime': 241.44502973556519, 'Gap': 0.0, 'TotalCollectedPrize': 1096.0, 'AveragePrizePerVehicle': 365.3333333333333}
# {'Instance': 'p4.3.p.txt', 'RunTime': 485.6406376361847, 'Gap': 0.0, 'TotalCollectedPrize': 1142.0, 'AveragePrizePerVehicle': 380.6666666666667}
# {'Instance': 'p4.3.q.txt', 'RunTime': 852.1285877227783, 'Gap': 0.0, 'TotalCollectedPrize': 1167.0, 'AveragePrizePerVehicle': 389.0}
# {'Instance': 'p4.3.r.txt', 'RunTime': 383.66478514671326, 'Gap': 0.0, 'TotalCollectedPrize': 1222.0, 'AveragePrizePerVehicle': 407.3333333333333}
# {'Instance': 'p4.3.s.txt', 'RunTime': 233.07434272766113, 'Gap': 0.0, 'TotalCollectedPrize': 1229.0, 'AveragePrizePerVehicle': 409.6666666666667}
# {'Instance': 'p4.3.t.txt', 'RunTime': 13430.477004289627, 'Gap': 0.0, 'TotalCollectedPrize': 1254.0, 'AveragePrizePerVehicle': 418.0}
# {'Instance': 'p4.4.a.txt', 'RunTime': 0.10919666290283203, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.b.txt', 'RunTime': 0.11160421371459961, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.c.txt', 'RunTime': 0.11722016334533691, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.d.txt', 'RunTime': 0.22024250030517578, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.e.txt', 'RunTime': 0.707005500793457, 'Gap': 0.0, 'TotalCollectedPrize': 183.0, 'AveragePrizePerVehicle': 45.75}
# {'Instance': 'p4.4.f.txt', 'RunTime': 9.072850465774536, 'Gap': 0.0, 'TotalCollectedPrize': 313.0, 'AveragePrizePerVehicle': 78.25}
# {'Instance': 'p4.4.g.txt', 'RunTime': 22.974290132522583, 'Gap': 0.0, 'TotalCollectedPrize': 439.0, 'AveragePrizePerVehicle': 109.75}
# {'Instance': 'p4.4.h.txt', 'RunTime': 33.03231334686279, 'Gap': 0.0, 'TotalCollectedPrize': 539.0, 'AveragePrizePerVehicle': 134.75}
# {'Instance': 'p4.4.i.txt', 'RunTime': 82.06167984008789, 'Gap': 0.0, 'TotalCollectedPrize': 645.0, 'AveragePrizePerVehicle': 161.25}
# {'Instance': 'p4.4.j.txt', 'RunTime': 258.9682891368866, 'Gap': 0.0, 'TotalCollectedPrize': 719.0, 'AveragePrizePerVehicle': 179.75}
# {'Instance': 'p4.4.k.txt', 'RunTime': 77.62190341949463, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.l.txt', 'RunTime': 99.38087749481201, 'Gap': 0.0, 'TotalCollectedPrize': 832.0, 'AveragePrizePerVehicle': 208.0}
# {'Instance': 'p4.4.m.txt', 'RunTime': 200.22070932388306, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.n.txt', 'RunTime': 294.854106426239, 'Gap': 0.0, 'TotalCollectedPrize': 949.0, 'AveragePrizePerVehicle': 237.25}
# {'Instance': 'p4.4.o.txt', 'RunTime': 351.9498574733734, 'Gap': 0.0, 'TotalCollectedPrize': 945.0, 'AveragePrizePerVehicle': 236.25}
# {'Instance': 'p4.4.p.txt', 'RunTime': 202.3715512752533, 'Gap': 0.0, 'TotalCollectedPrize': 1010.0, 'AveragePrizePerVehicle': 252.5}
# {'Instance': 'p4.4.q.txt', 'RunTime': 118.22188520431519, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}
# {'Instance': 'p4.4.r.txt', 'RunTime': 191.79149413108826, 'Gap': 0.0, 'TotalCollectedPrize': 1102.0, 'AveragePrizePerVehicle': 275.5}
# {'Instance': 'p4.4.s.txt', 'RunTime': 111.42648458480835, 'Gap': 0.0, 'TotalCollectedPrize': 1178.0, 'AveragePrizePerVehicle': 294.5}
# {'Instance': 'p4.4.t.txt', 'RunTime': 205.6519751548767, 'Gap': 0.0, 'TotalCollectedPrize': 0.0, 'AveragePrizePerVehicle': 0.0}

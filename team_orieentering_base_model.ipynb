# %%
import gurobipy as gp
from gurobipy import GRB
import numpy as np
import os
import time

# %%
def read_top_instance(file_path):
    with open(file_path, 'r') as file:
        # Read the first three lines
        n_line = file.readline().strip()
        m_line = file.readline().strip()
        tmax_line = file.readline().strip()

        # Parse n N
        _, N = n_line.split()
        N = int(N)

        # Parse m P
        _, P = m_line.split()
        P = int(P)

        # Parse tmax Tmax
        _, Tmax = tmax_line.split()
        Tmax = float(Tmax)

        # Read the remaining lines for each node
        nodes = []
        for i in range(N):
            line = file.readline().strip()
            if line == '':
                continue  # Skip empty lines
            x_str, y_str, s_str = line.split()
            x = float(x_str)
            y = float(y_str)
            s = float(s_str)
            nodes.append({'id': i, 'x': x, 'y': y, 'score': s})
        
        return N, P, Tmax, nodes

# %%
def compute_distance_matrix(nodes):
    N = len(nodes)
    distance_matrix = np.zeros((N, N))
    for i in range(N):
        xi, yi = nodes[i]['x'], nodes[i]['y']
        for j in range(N):
            xj, yj = nodes[j]['x'], nodes[j]['y']
            distance = np.hypot(xi - xj, yi - yj)
            distance_matrix[i][j] = distance
    return distance_matrix

# %%
def solve_top_gurobi(N, P, Tmax, nodes, distance_matrix):
    try:
        

        # Start timing
        start_time = time.time()
    
        # Create a new model
        model = gp.Model('TOP_base')
        model.Params.TimeLimit = 600
        model.Params.MIPGap = 0.01 
        model.Params.OutputFlag = 0

        # Sets
        V = range(N)  # Set of nodes
        K = range(P)  # Set of vehicles

        # Parameters
        c = distance_matrix
        p = [node['score'] for node in nodes]

        # Decision variables
        x = model.addVars(V, V, K, vtype=GRB.BINARY, name='x')
        y = model.addVars(V, K, vtype=GRB.BINARY, name='y')

        # Objective function
        model.setObjective(
            gp.quicksum(p[j] * y[j, k] for j in V for k in K),
            GRB.MAXIMIZE
        )

        # Constraints
        for k in K:
            # Time budget constraint
            model.addConstr(
                gp.quicksum(c[i][j] * x[i, j, k] for i in V for j in V if i != j) <= Tmax,
                name=f'TimeBudget_{k}'
            )

            # Flow conservation
            for j in V:
                if j != 0 and j != N - 1:
                    model.addConstr(
                        gp.quicksum(x[i, j, k] for i in V if i != j) == y[j, k],
                        name=f'FlowIn_{j}_{k}'
                    )
                    model.addConstr(
                        gp.quicksum(x[j, i, k] for i in V if i != j) == y[j, k],
                        name=f'FlowOut_{j}_{k}'
                    )

            # Start at start node
            model.addConstr(
                gp.quicksum(x[0, j, k] for j in V if j != 0) == 1,
                name=f'StartAtStartNode_{k}'
            )

            # End at end node
            model.addConstr(
                gp.quicksum(x[j, N - 1, k] for j in V if j != N - 1) == 1,
                name=f'EndAtEndNode_{k}'
            )

            # No flow into start node and no flow out of end node
            model.addConstr(
                gp.quicksum(x[j, 0, k] for j in V if j != 0) == 0,
                name=f'NoFlowIntoStartNode_{k}'
            )
            model.addConstr(
                gp.quicksum(x[N - 1, j, k] for j in V if j != N - 1) == 0,
                name=f'NoFlowOutOfEndNode_{k}'
            )

        # Each node is visited at most once
        for j in V:
            if j != 0 and j != N - 1:
                model.addConstr(
                    gp.quicksum(y[j, k] for k in K) <= 1,
                    name=f'VisitOnce_{j}'
                )

        # Find the maximum distance
        max_distance = np.max(distance_matrix)

        # Set the big M value
        M = Tmax + max_distance # Or consider using M = Tmax + max_distance if appropriate

        # Subtour elimination constraints (MTZ)
        u = model.addVars(V, K, vtype=GRB.CONTINUOUS, lb=0, ub=Tmax, name='u')

        for k in K:
            for i in V:
                for j in V:
                    if i != j :
                        model.addConstr(
                            u[i, k] + c[i][j] - M * (1 - x[i, j, k]) <= u[j, k],
                            name=f'Subtour_{i}_{j}_{k}'
                        )

        # Optimize the model
        model.optimize()
        end_time = time.time()
        run_time = end_time - start_time

        # Initialize the routes dictionary and collected prize
        routes = {}
        total_collected_prize = 0


        # Initialize the routes dictionary
        routes = {}

        # Extract the solution
        if model.Status == GRB.OPTIMAL or model.Status == GRB.TIME_LIMIT:
            for k in K:
                # Get the arcs used by vehicle k
                arcs = [(i, j) for i in V for j in V if x[i, j, k].X > 0.5]
                if not arcs:
                    continue
                # Store the arcs in the routes dictionary
                routes[k] = arcs

                # Reconstruct the route to calculate the collected prize
                arc_dict = {i: j for (i, j) in arcs}
                route = [0]
                current_node = 0
                while current_node != N - 1:
                    if current_node in arc_dict:
                        next_node = arc_dict[current_node]
                        route.append(next_node)
                        current_node = next_node
                    else:
                        break
                # Calculate collected prize for this vehicle
                collected_prize = sum(p[j] for j in route if j != 0 and j != N - 1)
                total_collected_prize += collected_prize
        elif model.Status == GRB.INFEASIBLE:
            print("Model is infeasible.")
            return None, None, None, None
        else:
            print(f"Optimization was stopped with status {model.Status}")
            return None, None, None, None

        # Get the optimality gap
        if model.Status == GRB.OPTIMAL:
            gap = 0.0
        else:
            gap = model.MIPGap

        return routes, run_time, gap, total_collected_prize

    except gp.GurobiError as e:
        print(f"Gurobi Error: {e}")
        return None, None, None, None
    except AttributeError as e:
        print(f"Attribute error: {e}")
        return None, None, None, None

# %%
def process_all_instances(directory_path):
    import csv
    import os

    # Prepare a list to store the results
    results = []

    csv_file = 'results.csv'
    with open(csv_file, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Instance', 'RunTime', 'Gap', 'TotalCollectedPrize', 'AveragePrizePerVehicle'])

    for filename in os.listdir(directory_path):
        if filename.endswith('.txt'):  # Adjust the extension if needed
            file_path = os.path.join(directory_path, filename)
            print(f"\nProcessing instance: {filename}")
            N, P, Tmax, nodes = read_top_instance(file_path)
            distance_matrix = compute_distance_matrix(nodes)
            routes, run_time, gap, total_collected_prize = solve_top_gurobi(N, P, Tmax, nodes, distance_matrix)

            if routes is not None:
                # Calculate average prize per vehicle
                num_vehicles_used = len(routes)
                if num_vehicles_used > 0:
                    average_prize = total_collected_prize / num_vehicles_used
                else:
                    average_prize = 0

                # Append the results
                results.append({
                    'Instance': filename,
                    'RunTime': run_time,
                    'Gap': gap,
                    'TotalCollectedPrize': total_collected_prize,
                    'AveragePrizePerVehicle': average_prize
                })

                # Write the results to the CSV file
                with open(csv_file, mode='a', newline='') as file:
                    writer = csv.writer(file)
                    writer.writerow([filename, run_time, gap, total_collected_prize, average_prize])
            else:
                print(f"No solution found for instance {filename}.")

    return results

# %%
#test with first instance
if __name__ == "__main__":
    # Path to a single instance file
    instance_file = 'Set_100_234/p4.2.a.txt'  # Replace with actual file name

    # Read the instance data
    N, P, Tmax, nodes = read_top_instance(instance_file)

    # Compute the distance matrix
    distance_matrix = compute_distance_matrix(nodes)

    # Solve the TOP using Gurobi
    results  = solve_top_gurobi(N, P, Tmax, nodes, distance_matrix)
    print(results)
# Out:
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
# ({0: [(0, 96), (7, 34), (23, 7), (34, 76), (76, 99), (96, 23)], 1: [(0, 14), (14, 52), (24, 99), (52, 55), (55, 78), (78, 24)]}, 13.382877588272095, 0.0, 206.0)

# %%
if __name__ == "__main__":
    # Set the path to your instance directory
    instance_directory = 'Set_100_234'  

    # Process all instances in the directory and collect results
    results = process_all_instances(instance_directory)

    print("\nSummary of Results:")
    for result in results:
        print(f"Instance: {result['Instance']}, Run Time: {result['RunTime']:.2f}s, "
              f"Gap: {result['Gap']*100:.2f}%, Total Prize: {result['TotalCollectedPrize']}, "
              f"Avg Prize/Vehicle: {result['AveragePrizePerVehicle']}")
# Out:
# Processing instance: p4.2.a.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
# Processing instance: p4.2.b.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.c.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.d.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.e.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.f.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.g.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.h.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.i.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.j.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.k.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.l.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.m.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.n.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.o.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.p.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.q.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.r.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.s.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.2.t.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.a.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
# Model is infeasible.
# No solution found for instance p4.3.a.txt.
#
# Processing instance: p4.3.b.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.c.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.d.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.e.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.f.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.g.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.h.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.i.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.j.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.k.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.l.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.m.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.n.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.o.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.p.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.q.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.r.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.s.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.3.t.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.a.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
# Model is infeasible.
# No solution found for instance p4.4.a.txt.
#
# Processing instance: p4.4.b.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
# Model is infeasible.
# No solution found for instance p4.4.b.txt.
#
# Processing instance: p4.4.c.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
# Model is infeasible.
# No solution found for instance p4.4.c.txt.
#
# Processing instance: p4.4.d.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.e.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.f.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.g.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.h.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.i.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.j.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.k.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.l.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.m.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.n.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.o.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.p.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.q.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.r.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.s.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Processing instance: p4.4.t.txt
# Set parameter TimeLimit to value 600
# Set parameter MIPGap to value 0.01
#
# Summary of Results:
# Instance: p4.2.a.txt, Run Time: 13.30s, Gap: 0.00%, Total Prize: 206.0, Avg Prize/Vehicle: 103.0
# Instance: p4.2.b.txt, Run Time: 25.63s, Gap: 0.00%, Total Prize: 341.0, Avg Prize/Vehicle: 170.5
# Instance: p4.2.c.txt, Run Time: 62.22s, Gap: 0.00%, Total Prize: 452.0, Avg Prize/Vehicle: 226.0
# Instance: p4.2.d.txt, Run Time: 603.63s, Gap: 3.95%, Total Prize: 531.0, Avg Prize/Vehicle: 265.5
# Instance: p4.2.e.txt, Run Time: 602.82s, Gap: 5.38%, Total Prize: 613.0, Avg Prize/Vehicle: 306.5
# Instance: p4.2.f.txt, Run Time: 605.99s, Gap: 9.13%, Total Prize: 679.0, Avg Prize/Vehicle: 339.5
# Instance: p4.2.g.txt, Run Time: 602.09s, Gap: 8.46%, Total Prize: 745.0, Avg Prize/Vehicle: 372.5
# Instance: p4.2.h.txt, Run Time: 602.04s, Gap: 10.76%, Total Prize: 790.0, Avg Prize/Vehicle: 395.0
# Instance: p4.2.i.txt, Run Time: 602.00s, Gap: 4.66%, Total Prize: 902.0, Avg Prize/Vehicle: 451.0
# Instance: p4.2.j.txt, Run Time: 602.08s, Gap: 15.71%, Total Prize: 885.0, Avg Prize/Vehicle: 442.5
# Instance: p4.2.k.txt, Run Time: 602.03s, Gap: 10.30%, Total Prize: 990.0, Avg Prize/Vehicle: 495.0
# Instance: p4.2.l.txt, Run Time: 602.20s, Gap: 10.87%, Total Prize: 1030.0, Avg Prize/Vehicle: 515.0
# Instance: p4.2.m.txt, Run Time: 602.25s, Gap: 9.01%, Total Prize: 1088.0, Avg Prize/Vehicle: 544.0
# Instance: p4.2.n.txt, Run Time: 602.13s, Gap: 7.21%, Total Prize: 1138.0, Avg Prize/Vehicle: 569.0
# Instance: p4.2.o.txt, Run Time: 602.21s, Gap: 8.14%, Total Prize: 1155.0, Avg Prize/Vehicle: 577.5
# Instance: p4.2.p.txt, Run Time: 602.16s, Gap: 4.70%, Total Prize: 1214.0, Avg Prize/Vehicle: 607.0
# Instance: p4.2.q.txt, Run Time: 602.16s, Gap: 2.71%, Total Prize: 1256.0, Avg Prize/Vehicle: 628.0
# Instance: p4.2.r.txt, Run Time: 602.29s, Gap: 5.32%, Total Prize: 1240.0, Avg Prize/Vehicle: 620.0
# Instance: p4.2.s.txt, Run Time: 602.29s, Gap: 2.27%, Total Prize: 1277.0, Avg Prize/Vehicle: 638.5
# Instance: p4.2.t.txt, Run Time: 602.15s, Gap: 4.56%, Total Prize: 1249.0, Avg Prize/Vehicle: 624.5
# Instance: p4.3.b.txt, Run Time: 7.05s, Gap: 0.00%, Total Prize: 38.0, Avg Prize/Vehicle: 12.666666666666666
# Instance: p4.3.c.txt, Run Time: 49.27s, Gap: 0.00%, Total Prize: 193.0, Avg Prize/Vehicle: 64.33333333333333
# Instance: p4.3.d.txt, Run Time: 338.18s, Gap: 0.00%, Total Prize: 335.0, Avg Prize/Vehicle: 111.66666666666667
# Instance: p4.3.e.txt, Run Time: 603.23s, Gap: 1.71%, Total Prize: 468.0, Avg Prize/Vehicle: 156.0
# Instance: p4.3.f.txt, Run Time: 603.19s, Gap: 2.07%, Total Prize: 579.0, Avg Prize/Vehicle: 193.0
# Instance: p4.3.g.txt, Run Time: 603.53s, Gap: 6.74%, Total Prize: 653.0, Avg Prize/Vehicle: 217.66666666666666
# Instance: p4.3.h.txt, Run Time: 603.27s, Gap: 12.02%, Total Prize: 724.0, Avg Prize/Vehicle: 241.33333333333334
# Instance: p4.3.i.txt, Run Time: 603.58s, Gap: 13.12%, Total Prize: 800.0, Avg Prize/Vehicle: 266.6666666666667
# Instance: p4.3.j.txt, Run Time: 603.22s, Gap: 11.81%, Total Prize: 855.0, Avg Prize/Vehicle: 285.0
# Instance: p4.3.k.txt, Run Time: 603.62s, Gap: 14.25%, Total Prize: 912.0, Avg Prize/Vehicle: 304.0
# Instance: p4.3.l.txt, Run Time: 603.27s, Gap: 15.01%, Total Prize: 953.0, Avg Prize/Vehicle: 317.6666666666667
# Instance: p4.3.m.txt, Run Time: 603.23s, Gap: 11.92%, Total Prize: 1040.0, Avg Prize/Vehicle: 346.6666666666667
# Instance: p4.3.n.txt, Run Time: 604.13s, Gap: 11.68%, Total Prize: 1079.0, Avg Prize/Vehicle: 359.6666666666667
# Instance: p4.3.o.txt, Run Time: 603.26s, Gap: 9.97%, Total Prize: 1123.0, Avg Prize/Vehicle: 374.3333333333333
# Instance: p4.3.p.txt, Run Time: 603.18s, Gap: 3.95%, Total Prize: 1215.0, Avg Prize/Vehicle: 405.0
# Instance: p4.3.q.txt, Run Time: 603.33s, Gap: 5.77%, Total Prize: 1213.0, Avg Prize/Vehicle: 404.3333333333333
# Instance: p4.3.r.txt, Run Time: 603.99s, Gap: 5.35%, Total Prize: 1233.0, Avg Prize/Vehicle: 411.0
# Instance: p4.3.s.txt, Run Time: 603.35s, Gap: 6.27%, Total Prize: 1229.0, Avg Prize/Vehicle: 409.6666666666667
# Instance: p4.3.t.txt, Run Time: 603.24s, Gap: 7.31%, Total Prize: 1217.0, Avg Prize/Vehicle: 405.6666666666667
# Instance: p4.4.d.txt, Run Time: 8.28s, Gap: 0.00%, Total Prize: 38.0, Avg Prize/Vehicle: 9.5
# Instance: p4.4.e.txt, Run Time: 71.61s, Gap: 0.00%, Total Prize: 183.0, Avg Prize/Vehicle: 45.75
# Instance: p4.4.f.txt, Run Time: 604.38s, Gap: 15.12%, Total Prize: 324.0, Avg Prize/Vehicle: 81.0
# Instance: p4.4.g.txt, Run Time: 604.57s, Gap: 16.23%, Total Prize: 456.0, Avg Prize/Vehicle: 114.0
# Instance: p4.4.h.txt, Run Time: 604.69s, Gap: 14.36%, Total Prize: 571.0, Avg Prize/Vehicle: 142.75
# Instance: p4.4.i.txt, Run Time: 604.62s, Gap: 19.30%, Total Prize: 632.0, Avg Prize/Vehicle: 158.0
# Instance: p4.4.j.txt, Run Time: 604.31s, Gap: 34.94%, Total Prize: 707.0, Avg Prize/Vehicle: 176.75
# Instance: p4.4.k.txt, Run Time: 604.74s, Gap: 22.06%, Total Prize: 775.0, Avg Prize/Vehicle: 193.75
# Instance: p4.4.l.txt, Run Time: 605.50s, Gap: 17.89%, Total Prize: 855.0, Avg Prize/Vehicle: 213.75
# Instance: p4.4.m.txt, Run Time: 607.07s, Gap: 19.22%, Total Prize: 900.0, Avg Prize/Vehicle: 225.0
# Instance: p4.4.n.txt, Run Time: 604.22s, Gap: 20.91%, Total Prize: 942.0, Avg Prize/Vehicle: 235.5
# Instance: p4.4.o.txt, Run Time: 604.75s, Gap: 31.08%, Total Prize: 962.0, Avg Prize/Vehicle: 240.5
# Instance: p4.4.p.txt, Run Time: 604.77s, Gap: 23.95%, Total Prize: 1002.0, Avg Prize/Vehicle: 250.5
# Instance: p4.4.q.txt, Run Time: 606.10s, Gap: 15.81%, Total Prize: 1094.0, Avg Prize/Vehicle: 273.5
# Instance: p4.4.r.txt, Run Time: 604.27s, Gap: 21.28%, Total Prize: 1062.0, Avg Prize/Vehicle: 265.5
# Instance: p4.4.s.txt, Run Time: 604.31s, Gap: 14.06%, Total Prize: 1145.0, Avg Prize/Vehicle: 286.25
# Instance: p4.4.t.txt, Run Time: 604.25s, Gap: 8.47%, Total Prize: 1204.0, Avg Prize/Vehicle: 301.0

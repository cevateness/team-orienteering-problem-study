# %%
import random
import math
import copy
from collections import deque

# %%
def read_top_instance(file_path):
    with open(file_path, 'r') as file:
        # Read the first three lines
        n_line = file.readline().strip()
        m_line = file.readline().strip()
        tmax_line = file.readline().strip()

        # Parse n N
        _, N = n_line.split()
        N = int(N)

        # Parse m P
        _, P = m_line.split()
        P = int(P)

        # Parse tmax Tmax
        _, Tmax = tmax_line.split()
        Tmax = float(Tmax)

        # Read the remaining lines for each node
        nodes = []
        for i in range(N):
            line = file.readline().strip()
            if line == '':
                continue  # Skip empty lines
            x_str, y_str, s_str = line.split()
            x = float(x_str)
            y = float(y_str)
            s = float(s_str)
            nodes.append({'id': i, 'x': x, 'y': y, 'score': s})

        return N, P, Tmax, nodes

# %%
# define problem instance. 
class ProblemInstance:
    def __init__(self, file_path):
        """
        Initialize the problem instance by reading data from a file.

        :param file_path: Path to the instance data file
        """
        self.N, self.P, self.Tmax, self.nodes = read_top_instance(file_path)
        self.distance_matrix = self.compute_distance_matrix()

    def compute_distance_matrix(self):
        """
        Compute the Euclidean distance matrix keyed by node IDs.

        :return: A dictionary of dictionaries representing the distance matrix, 
                where distance_matrix[id1][id2] = distance between node id1 and id2.
        """
        # Initialize the distance matrix as a nested dictionary
        distance_matrix = {}
        
        # Extract all node IDs and coordinates for convenience
        nodes_info = {node['id']: (node['x'], node['y']) for node in self.nodes}

        for id1, (x1, y1) in nodes_info.items():
            distance_matrix[id1] = {}
            for id2, (x2, y2) in nodes_info.items():
                if id1 == id2:
                    distance_matrix[id1][id2] = 0.0
                else:
                    distance = math.hypot(x1 - x2, y1 - y2)
                    distance_matrix[id1][id2] = distance

        return distance_matrix

# %%
class HALNS:
    def __init__(self, file_path, parameters):
        """
        Initialize the HALNS heuristic with the given problem instance file and parameters.

        :param file_path: Path to the TOP instance data file
        :param parameters: A dictionary containing algorithm parameters
        """
        self.problem = ProblemInstance(file_path)
        self.params = parameters

        # Initialize variables
        self.s_best = None
        self.s_adm = None
        self.T = self.params['T0']
        self.seg = 0
        self.iteration_best = 0

        # Initialize scores for strategies and operators
        # Mapped from the paper: dynamic profit/time, highest profit, random, LRFI
        self.selection_strategies = [
            'dynamic_profit_per_time', 
            'highest_profit',
            'random',
            'lrfi'
        ]

        self.removal_ops = [
            'random_removal',
            'lowest_profit_removal',
            'largest_saving_removal',
            'route_removal',
            'sequence_removal'
        ]
        
        self.insertion_ops = [
            'first_available',
            'last_available',
            'random_available',
            'best_overall_position',
            'best_position'
        ]

        self.selection_scores = {}
        self.selection_observed_scores = {}
        self.selection_counts = {}

        self.removal_scores = {}
        self.removal_observed_scores = {}
        self.removal_counts = {}

        self.insertion_scores = {}
        self.insertion_observed_scores = {}
        self.insertion_counts = {}

        # Keep track of last removed nodes for LRFI strategy
        self.last_removed_nodes = deque(maxlen=self.params.get('lrfi_count', 10))



    def _compute_route_time(self, route):
        dm = self.problem.distance_matrix
        time = 0.0
        for i in range(len(route)-1):
            time += dm[route[i]][route[i+1]]
        return time

    def _compute_solution_travel_time(self, solution):
        return sum(self._compute_route_time(r) for r in solution)

    def _is_feasible_insertion(self, route, pos, node):
        # Check feasibility of inserting node at route[pos]
        # For simplicity, assume feasibility = route time <= Tmax after insertion
        dm = self.problem.distance_matrix
        new_route = route[:pos] + [node] + route[pos:]
        return self._compute_route_time(new_route) <= self.problem.Tmax

    def _insert_node_in_position(self, route, pos, node):
        route.insert(pos, node)

    def _incremental_time_for_insertion(self, route, pos, node):
        dm = self.problem.distance_matrix
        before = dm[route[pos-1]][route[pos]]
        after = dm[route[pos-1]][node] + dm[node][route[pos]]
        return after - before

    def node_elimination_procedure(self):
        """
        Apply a node elimination procedure.
        This procedure removes nodes that cannot be serviced within the allowed time budget.
        A node i is eliminated if even the direct route s -> i -> e exceeds Tmax.
        """
        print("Applying node elimination procedure...")

        # Extract relevant information from the problem instance
        N = self.problem.N
        distance_matrix = self.problem.distance_matrix
        Tmax = self.problem.Tmax

        start_node = 0
        end_node = N - 1

        # Mandatory nodes (start and end) cannot be eliminated
        # We'll create a new list of nodes that remain feasible after elimination
        feasible_nodes = []

        # For each node, check feasibility:
        for node in self.problem.nodes:
            i = node['id']
            
            # Skip start and end nodes as they must remain
            if i == start_node or i == end_node:
                feasible_nodes.append(node)
                continue

            # Compute minimal route time s -> i -> e
            T_sie = distance_matrix[start_node][i] + distance_matrix[i][end_node]

            if T_sie <= Tmax:
                # This node could potentially be serviced in some feasible route
                feasible_nodes.append(node)
            else:
                # Node cannot be serviced within Tmax, so it is eliminated
                print(f"Eliminating node {i} due to infeasibility (s->i->e exceeds Tmax).")

        # Update the problem instance with the reduced set of nodes
        self.problem.nodes = feasible_nodes
        # Update N to reflect the new number of nodes
        self.problem.N = len(feasible_nodes)

        # Create a dictionary keyed by node id for direct access:
        self.problem.node_dict = {node['id']: node for node in self.problem.nodes}

        print("Node elimination procedure completed.")
    
    def construct_initial_solution(self):
        print("Constructing initial solution using the nearest neighbor algorithm...")

        N = self.problem.N
        start_node = 0
        end_node = N - 1

        unvisited = {nid for nid in self.problem.node_dict.keys() if nid not in {start_node, end_node}}
        paths = [[start_node, end_node] for _ in range(self.problem.P)]
        current_times = []
        for p in range(self.problem.P):
            initial_time = self.problem.distance_matrix[start_node][end_node]
            current_times.append(initial_time)

        current_positions = [start_node for _ in range(self.problem.P)]

        while unvisited:
            improvement = False
            for p in range(self.problem.P):
                last_node = current_positions[p]
                best_node = None
                best_score = -1
                best_distance = float('inf')

                for node_id in unvisited:
                    distance = self.problem.distance_matrix[last_node][node_id]
                    distance_to_end = self.problem.distance_matrix[node_id][end_node]
                    new_total_time = current_times[p] - self.problem.distance_matrix[last_node][end_node] + distance + distance_to_end

                    if new_total_time <= self.problem.Tmax:
                        node_score = self.problem.node_dict[node_id]['score']  
                        heuristic = node_score / (distance + 1)
                        if heuristic > best_score:
                            best_score = heuristic
                            best_node = node_id
                            best_distance = distance

                if best_node is not None:
                    paths[p].insert(-1, best_node)
                    unvisited.remove(best_node)
                    current_times[p] = current_times[p] - self.problem.distance_matrix[last_node][end_node] + best_distance + self.problem.distance_matrix[best_node][end_node]
                    current_positions[p] = best_node
                    improvement = True
                    print(f"Path {p + 1}: Added node {best_node} (Score: {self.problem.node_dict[best_node]['score']}, Distance: {best_distance:.2f})")

            if not improvement:
                print("No further nodes can be added without exceeding Tmax.")
                break

        for p in range(self.problem.P):
            if paths[p][-1] != end_node:
                paths[p].append(end_node)
                print(f"Path {p + 1}: Ensured ending at node {end_node}. Total time: {current_times[p]:.2f}")

        self.s_best = paths
        self.s_adm = copy.deepcopy(paths)
        print("Initial solution constructed with time budget consideration.")
        return paths
        
    def initialize_scores(self):
        """
        Initialize the scores of the node selection strategy and the removal and insertion operators.
        """
        print("Initializing scores for strategies and operators...")

        # Each strategy/operator starts with a score of 1.0 as per the described approach
        for strat in self.selection_strategies:
            self.selection_scores[strat] = 1.0
            self.selection_observed_scores[strat] = 0.0
            self.selection_counts[strat] = 0

        for rem in self.removal_ops:
            self.removal_scores[rem] = 1.0
            self.removal_observed_scores[rem] = 0.0
            self.removal_counts[rem] = 0

        for ins in self.insertion_ops:
            self.insertion_scores[ins] = 1.0
            self.insertion_observed_scores[ins] = 0.0
            self.insertion_counts[ins] = 0
    
    def select_node_selection_strategy(self):
        """
        Select a node selection strategy based on current scores.
        A roulette wheel selection is performed:
        P_k = p_k / sum_of_all_p
        The strategies are:
        1. dynamic_profit_per_time
        2. highest_profit
        3. random
        4. lrfi
        """
        print("Selecting node selection strategy...")
        total_score = sum(self.selection_scores.values())
        r = random.uniform(0, total_score)
        cumulative = 0.0
        for strat, score in self.selection_scores.items():
            cumulative += score
            if r <= cumulative:
                return strat
        # Fallback in case of numerical issues
        return self.selection_strategies[0]
    
    def select_removal_insertion_operators(self):
        """
        Select removal and insertion operators based on current scores via roulette wheel selection.
        """
        print("Selecting removal and insertion operators...")

        # Removal operator selection
        total_score_rem = sum(self.removal_scores.values())
        r_rem = random.uniform(0, total_score_rem)
        cumulative_rem = 0.0
        selected_removal = None
        for rem, score in self.removal_scores.items():
            cumulative_rem += score
            if r_rem <= cumulative_rem:
                selected_removal = rem
                break

        # Insertion operator selection
        total_score_ins = sum(self.insertion_scores.values())
        r_ins = random.uniform(0, total_score_ins)
        cumulative_ins = 0.0
        selected_insertion = None
        for ins, score in self.insertion_scores.items():
            cumulative_ins += score
            if r_ins <= cumulative_ins:
                selected_insertion = ins
                break

        return selected_removal, selected_insertion
    
    def remove_nodes(self, solution, b, removal_operator):
            print(f"Removing {b} nodes using {removal_operator}...")
            
            if removal_operator == 'random_removal':
                removed = self._remove_random_nodes(solution, b)
            elif removal_operator == 'lowest_profit_removal':
                removed = self._remove_lowest_profit_nodes(solution, b)
            elif removal_operator == 'largest_saving_removal':
                removed = self._remove_largest_saving_nodes(solution, b)
            elif removal_operator == 'route_removal':
                removed = self._remove_route(solution)
            elif removal_operator == 'sequence_removal':
                removed = self._remove_sequence(solution, b)
            else:
                # Default to random removal if unknown
                removed = self._remove_random_nodes(solution, b)
            
            # Update solution by removing chosen nodes
            for route in solution:
                route[:] = [x for x in route if x not in removed]

            # Update LRFI queue
            for n in removed:
                self.last_removed_nodes.appendleft(n)
            
            return solution

    def _remove_random_nodes(self, solution, b):
        nodes = [n for route in solution for n in route if n not in (0, self.problem.N - 1)]
        removed = set()
        for _ in range(min(b, len(nodes))):
            n = random.choice(nodes)
            nodes.remove(n)
            removed.add(n)
        return removed

    def _remove_lowest_profit_nodes(self, solution, b):
        # Weighted removal based on lowest profit: nodes with lower profit are more likely to be chosen
        nodes = [n for route in solution for n in route if n not in (0, self.problem.N - 1)]
        if not nodes:
            return set()
        
        # Sort by profit ascending
        nodes.sort(key=lambda x: self.problem.node_dict[x]['score'])
        total_profit = sum(self.problem.node_dict[n]['score'] for n in nodes) + 1e-9
        removed = set()
        for _ in range(min(b, len(nodes))):
            # Roulette wheel giving higher chance to lower profit nodes
            r = random.uniform(0, total_profit)
            cumulative = 0.0
            chosen = nodes[0]
            for n in nodes:
                cumulative += self.problem.node_dict[n]['score']
                if r <= cumulative:
                    chosen = n
                    break
            removed.add(chosen)
            nodes.remove(chosen)
            total_profit -= self.problem.node_dict[chosen]['score']
        return removed

    def _remove_largest_saving_nodes(self, solution, b):
        # Compute saving in travel time for removing each node: D(s) - D(s\i)
        # First compute D(s)
        original_time = self._compute_solution_travel_time(solution)

        # For each node, compute saving
        candidates = []
        for r_idx, route in enumerate(solution):
            for i in range(1, len(route)-1):
                n = route[i]
                # Temporarily remove node n and compute new time
                temp_route = route[:i] + route[i+1:]
                temp_sol = solution[:r_idx] + [temp_route] + solution[r_idx+1:]
                new_time = self._compute_solution_travel_time(temp_sol)
                saving = original_time - new_time
                candidates.append((n, saving))
        
        if not candidates:
            return set()

        # Sort by saving descending, then use roulette wheel with weights = saving
        total_saving = sum(s for _, s in candidates) + 1e-9
        removed = set()
        nodes_list = candidates[:]
        # Remove b nodes with preference to largest saving
        for _ in range(min(b, len(nodes_list))):
            r = random.uniform(0, total_saving)
            cumulative = 0.0
            chosen = nodes_list[0][0]
            for (nd, sv) in nodes_list:
                cumulative += sv
                if r <= cumulative:
                    chosen = nd
                    break
            removed.add(chosen)
            # Remove chosen from candidate list and adjust total_saving
            for idx, (nd, sv) in enumerate(nodes_list):
                if nd == chosen:
                    total_saving -= sv
                    del nodes_list[idx]
                    break
        return removed

    def _remove_route(self, solution):
        # Randomly select a route (other than maybe a trivial one) and remove all nodes from it
        non_empty_routes = [r for r in solution if len(r) > 2]
        if not non_empty_routes:
            # If no non-empty routes, nothing to remove
            return set()
        route = random.choice(non_empty_routes)
        # Remove all non-depot nodes
        removed = set(route[1:-1])
        return removed

    def _remove_sequence(self, solution, b):
        # Randomly select a route and remove a sequence of b consecutive nodes (excluding depots)
        routes_with_enough_nodes = [r for r in solution if len(r)-2 >= b]
        if not routes_with_enough_nodes:
            # Fall back to random removal if not possible
            return self._remove_random_nodes(solution, b)
        route = random.choice(routes_with_enough_nodes)
        start_idx = random.randint(1, len(route)-1 - b)
        removed = set(route[start_idx:start_idx+b])
        return removed

    # insertion operators
    def insert_nodes(self, solution, insertion_operator, strategy):
        print(f"Inserting nodes using {insertion_operator} with strategy {strategy}...")
        
        # Determine nodes to insert based on strategy (already chosen and ordered)
        visited = {nid for r in solution for nid in r}
        start_node = 0
        end_node = self.problem.N - 1
        unvisited = set(self.problem.node_dict.keys()) - visited - {start_node, end_node}

        # Strategy decides the order in which nodes are considered. This is handled separately.
        # Here we assume the `strategy` has already selected insertion_order in a previous step.
        # For demonstration, let's assume we have the insertion_order from node selection strategy step:
        # In real code, you'd integrate your node selection strategy logic here.
        insertion_order = self._get_insertion_order(unvisited, strategy)

        # Apply the chosen insertion operator to insert nodes in the given order
        if insertion_operator == 'first_available':
            solution = self._insert_nodes_first_available(solution, insertion_order)
        elif insertion_operator == 'last_available':
            solution = self._insert_nodes_last_available(solution, insertion_order)
        elif insertion_operator == 'random_available':
            solution = self._insert_nodes_random_available(solution, insertion_order)
        elif insertion_operator == 'best_overall_position':
            solution = self._insert_nodes_best_overall_position(solution, insertion_order)
        elif insertion_operator == 'best_position':
            solution = self._insert_nodes_best_position(solution, insertion_order)
        else:
            # Default to a simple operator, e.g., first_available
            solution = self._insert_nodes_first_available(solution, insertion_order)
        
        return solution

    def _get_insertion_order(self, unvisited, strategy):
        """
        Determine the order in which nodes from 'unvisited' should be considered for insertion
        based on the selected node selection strategy.
        Strategies:
        - dynamic_profit_per_time
        - highest_profit
        - random
        - lrfi
        """
        if not unvisited:
            return []

        if strategy == 'dynamic_profit_per_time':
            # Compute p_i / D(s+i) for each node i
            candidates = []
            for n in unvisited:
                profit = self.problem.node_dict[n]['score']
                incremental_time = self._compute_min_incremental_time(self.s_adm, n)
                ratio = profit / incremental_time if incremental_time > 0 else float('inf')
                candidates.append((n, ratio))
            # Sort by ratio descending
            candidates.sort(key=lambda x: x[1], reverse=True)
            insertion_list = [n for n, _ in candidates]

        elif strategy == 'highest_profit':
            # Roulette wheel based on profit
            temp_nodes = list(unvisited)
            insertion_list = []
            total_profit = sum(self.problem.node_dict[n]['score'] for n in temp_nodes) + 1e-9
            while temp_nodes:
                r = random.uniform(0, total_profit)
                cumulative = 0.0
                chosen = temp_nodes[0]
                for node_id in temp_nodes:
                    cumulative += self.problem.node_dict[node_id]['score']
                    if r <= cumulative:
                        chosen = node_id
                        break
                insertion_list.append(chosen)
                temp_nodes.remove(chosen)
                total_profit -= self.problem.node_dict[chosen]['score']

        elif strategy == 'random':
            insertion_list = list(unvisited)
            random.shuffle(insertion_list)

        elif strategy == 'lrfi':
            # Insert last removed nodes first if they are still unvisited
            lrfi_candidates = [n for n in self.last_removed_nodes if n in unvisited]
            # Remove them from unvisited
            remainder = list(unvisited - set(lrfi_candidates))
            # For remainder, fallback to random (or another strategy if desired)
            random.shuffle(remainder)
            insertion_list = lrfi_candidates + remainder

        else:
            # Default fallback - random
            insertion_list = list(unvisited)
            random.shuffle(insertion_list)

        return insertion_list


    def _compute_min_incremental_time(self, solution, node):
        """
        Compute the minimal incremental travel time of inserting 'node' anywhere in the given 'solution'.
        """
        min_increment = float('inf')
        dm = self.problem.distance_matrix
        for r_idx, route in enumerate(solution):
            for i in range(len(route)-1):
                a, b = route[i], route[i+1]
                current_time = dm[a][b]
                new_time = dm[a][node] + dm[node][b]
                increment = new_time - current_time
                if increment < min_increment:
                    min_increment = increment
        return min_increment if min_increment != float('inf') else 1e9  # Large number if no feasible insertion

    # Insertion methods
    def _insert_nodes_first_available(self, solution, nodes):
        # For each node, insert at the first feasible position in some route
        for node in nodes:
            # Try each route in order, from start to end
            inserted = False
            for route in solution:
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        self._insert_node_in_position(route, pos, node)
                        inserted = True
                        break
                if inserted:
                    break
        return solution

    def _insert_nodes_last_available(self, solution, nodes):
        # For each node, insert at the last feasible position scanning routes from end to start
        for node in nodes:
            inserted = False
            for route in solution:
                for pos in range(len(route)-1, 0, -1):
                    if self._is_feasible_insertion(route, pos, node):
                        self._insert_node_in_position(route, pos, node)
                        inserted = True
                        break
                if inserted:
                    break
        return solution

    def _insert_nodes_random_available(self, solution, nodes):
        # For each node, find all feasible positions and choose one at random
        for node in nodes:
            candidates = []
            for r_idx, route in enumerate(solution):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        candidates.append((r_idx, pos))
            if candidates:
                r_idx, pos = random.choice(candidates)
                self._insert_node_in_position(solution[r_idx], pos, node)
        return solution

    def _insert_nodes_best_overall_position(self, solution, nodes):
        # For each node, test all feasible insertions and choose the one minimizing total solution travel time
        # This can be expensive, but we do it as described.
        original_time = self._compute_solution_travel_time(solution)
        for node in nodes:
            best_delta = float('inf')
            best_route = None
            best_pos = None
            for r_idx, route in enumerate(solution):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        # Insert temporarily and check total time
                        temp_sol = copy.deepcopy(solution)
                        self._insert_node_in_position(temp_sol[r_idx], pos, node)
                        new_time = self._compute_solution_travel_time(temp_sol)
                        delta = new_time - original_time
                        if delta < best_delta:
                            best_delta = delta
                            best_route = r_idx
                            best_pos = pos
            if best_route is not None:
                self._insert_node_in_position(solution[best_route], best_pos, node)
                # Update original_time after insertion
                original_time += best_delta
        return solution

    def _insert_nodes_best_position(self, solution, nodes):
        # For each node, find the insertion that minimizes local incremental time
        for node in nodes:
            best_increment = float('inf')
            best_route = None
            best_pos = None
            for r_idx, route in enumerate(solution):
                for pos in range(1, len(route)):
                    if self._is_feasible_insertion(route, pos, node):
                        increment = self._incremental_time_for_insertion(route, pos, node)
                        if increment < best_increment:
                            best_increment = increment
                            best_route = r_idx
                            best_pos = pos
            if best_route is not None:
                self._insert_node_in_position(solution[best_route], best_pos, node)
        return solution
    def evaluate_solution(self, solution):
        visited = set()
        for route in solution:
            for nid in route:
                visited.add(nid)
                
        total_score = 0.0
        for nid in visited:
            total_score += self.problem.node_dict[nid]['score']
        
        return total_score
    
    def apply_local_search(self, solution):
        """
        Apply local search procedures on the solution.
        Placeholder for the actual implementation.
        
        :param solution: Solution to improve
        :return: Improved solution
        """
        print("Applying local search procedures...")
        # TODO: Implement local search
        improved_solution = copy.deepcopy(solution)  # Replace with actual improvement
        return improved_solution
    
    def generate_and_solve_SROP(self, solution):
        """
        Generate and solve a SROP (Sub-Route Optimization Problem).
        Placeholder for the actual implementation.
        
        :param solution: Current solution
        :return: Optimized solution
        """
        print("Generating and solving SROP...")
        # TODO: Implement SROP generation and solving
        optimized_solution = copy.deepcopy(solution)  # Replace with actual optimization
        return optimized_solution
    
    def generate_and_solve_SPP(self, solution):
        """
        Generate and solve a SPP (Single Path Problem).
        Placeholder for the actual implementation.
        
        :param solution: Current solution
        :return: Optimized solution
        """
        print("Generating and solving SPP...")
        # TODO: Implement SPP generation and solving
        optimized_solution = copy.deepcopy(solution)  # Replace with actual optimization
        return optimized_solution
    
    def update_scores(self):
        """
        Update the scores of the ALNS operators and insertion strategies at the end of a segment.
        
        p_{k,q+1} = kappa * (observed_score_k / n_k) + (1 - kappa)*p_{k,q}, if n_k > 0
        If n_k = 0, score remains unchanged.
        After updating, observed scores and counts reset.
        """
        print("Updating scores of the ALNS operators and insertion strategies...")

        kappa = self.params.get('kappa', 0.5)

        def update_category_scores(scores, observed_scores, counts):
            for k in scores.keys():
                n_k = counts[k]
                if n_k > 0:
                    old_score = scores[k]
                    new_score = kappa * (observed_scores[k] / n_k) + (1 - kappa) * old_score
                    scores[k] = new_score
                # Reset for next segment
                observed_scores[k] = 0.0
                counts[k] = 0

        update_category_scores(self.selection_scores, self.selection_observed_scores, self.selection_counts)
        update_category_scores(self.removal_scores, self.removal_observed_scores, self.removal_counts)
        update_category_scores(self.insertion_scores, self.insertion_observed_scores, self.insertion_counts)

        print("Score update completed.")
        
    def run(self):
            # Step 1: Apply node elimination procedure
            self.node_elimination_procedure()
            
            # Step 2: Construct initial solution using the nearest neighbor algorithm
            initial_solution = self.construct_initial_solution()
            self.s_best = initial_solution
            self.s_adm = initial_solution
            
            # Initialize parameters
            self.T = self.params['T0']
            self.seg = 0
            self.iteration_best = 0
            
            # Step 4: Initialize scores
            self.initialize_scores()

            # Extract q parameters
            q1 = self.params.get('q1', 10.0)
            q2 = self.params.get('q2', 5.0)
            q3 = self.params.get('q3', 1.0)

            # Step 5: Main loop
            while self.seg < self.params['Nseg'] and self.iteration_best < self.params['iteration_best_max']:
                print(f"\n--- Segment {self.seg + 1} ---")
                iteration = 0
                
                while iteration < self.params['iteration_max']:
                    print(f"\nIteration {iteration + 1} within Segment {self.seg + 1}")
                    s = copy.deepcopy(self.s_adm)
                    
                    # Generate b (number of nodes to remove)
                    # For safety, ensure b does not exceed solution complexity; using a simple logic:
                    b = random.randint(1, max(1, int(0.25*sum(len(p) for p in s)-2*len(s))))
                    print(f"Number of nodes to remove: {b}")
                    
                    # Select node selection strategy
                    c = self.select_node_selection_strategy()
                    
                    # Select removal and insertion operators
                    R, I = self.select_removal_insertion_operators()
                    
                    # Count usage
                    self.selection_counts[c] += 1
                    self.removal_counts[R] += 1
                    self.insertion_counts[I] += 1

                    # Remove b nodes using R
                    s = self.remove_nodes(s, b, R)
                    
                    # Insert nodes using I following c
                    s = self.insert_nodes(s, I, c)
                    
                    # Generate a random number d in [0,1]
                    d = random.uniform(0, 1)
                    print(f"Random number d: {d}")
                    
                    # Evaluate solutions
                    f_s = self.evaluate_solution(s)
                    f_sadm = self.evaluate_solution(self.s_adm)
                    f_sbest = self.evaluate_solution(self.s_best)
                    
                    if f_s >= f_sadm or d <= math.exp((f_s - f_sadm) / self.T):
                        print("Solution accepted based on acceptance criteria.")
                        
                        # Determine q increment based on improvement
                        if f_s > f_sbest:
                            q_value = q1
                        elif f_s > f_sadm:
                            q_value = q2
                        else:
                            q_value = q3

                        # Increment observed scores
                        self.selection_observed_scores[c] += q_value
                        self.removal_observed_scores[R] += q_value
                        self.insertion_observed_scores[I] += q_value

                        # If f(s) > f(sadm), apply local search
                        if f_s > f_sadm:
                            s = self.apply_local_search(s)
                            f_s = self.evaluate_solution(s)
                            print("Applied local search.")

                        # If f(s) > f(s_best), update sbest and reset iteration_best
                        if f_s > f_sbest:
                            print("New best solution found. Generating and solving SROP...")
                            s = self.generate_and_solve_SROP(s)
                            self.s_best = copy.deepcopy(s)
                            self.iteration_best = 0
                            print("s_best updated.")
                        else:
                            self.iteration_best += 1
                            print(f"Iteration best incremented to {self.iteration_best}.")
                        
                        self.s_adm = copy.deepcopy(s)
                    else:
                        # Not accepted
                        self.iteration_best += 1
                        print(f"Solution not accepted. Iteration best incremented to {self.iteration_best}.")
                    
                    # Temperature check
                    if self.T <= self.params['T_min']:
                        print("Temperature below minimum. Resetting temperature and generating SPP...")
                        self.T = self.params['T0']
                        s = self.generate_and_solve_SPP(s)
                        
                        if self.evaluate_solution(s) > self.evaluate_solution(self.s_best):
                            self.iteration_best = 0
                            print("Improved solution found after SPP.")
                        
                        self.s_best = copy.deepcopy(s)
                        self.s_adm = copy.deepcopy(s)
                    
                    # Update temperature and iteration
                    self.T *= self.params['cooling_rate']
                    iteration += 1
                    print(f"Temperature updated to {self.T}.")
                
                # Update scores at the end of the segment
                self.update_scores()
                
                # Increment segment
                self.seg += 1
                print(f"Segment {self.seg} completed.")
            
            # Generate and solve a final SPP
            print("\nGenerating and solving final SPP...")
            self.s_best = self.generate_and_solve_SPP(self.s_best)
            
            # Final solution
            print("Final solution obtained.")
            return self.s_best

# %%
if __name__ == "__main__":
    # Define the path to your TOP instance data file
    file_path = 'Set_100_234/p4.2.a.txt' # 3 paths does not properly work currently!

    parameters = {
        'T0': 95,              # Initial temperature for the simulated annealing mechanism.
        'T_min': 0.0001,              # Minimum temperature below which we reset temperature and solve a SPP.
        'cooling_rate': 0.9999,    # The factor by which the temperature is multiplied after each iteration.
        'Nseg': 100,              # Number of segments (run segments) after which score updates occur.
        'iteration_max': 1000,  # Maximum number of iterations per segment.
        'iteration_best_max': 50,# Maximum number of consecutive iterations without improvement before stopping.
        'kappa': 0.85,            # Reaction factor for updating operator/strategy scores.
        'q1': 20.0,              # Score increment if a new best solution is found.
        'q2': 5.0,               # Score increment if the solution improves the last admissible one but is not a best.
        'q3': 1.0,               # Score increment if the solution is accepted but does not improve the last admissible.
        'lrfi_count': 10         # Maximum number of nodes to track for "Last Removed First Inserted" strategy.
    }

    # Initialize HALNS heuristic with the problem instance file and parameters
    halns = HALNS(file_path, parameters)

    # Run HALNS to obtain the best solution
    best_solution = halns.run()

    # Output the best solution
    print("Best Solution:", best_solution)

    total_prize = halns.evaluate_solution(best_solution)
    print("Total Prize Collected:", total_prize)
# Out:
# Applying node elimination procedure...
# Eliminating node 1 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 2 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 3 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 5 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 8 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 11 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 12 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 13 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 15 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 16 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 17 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 18 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 19 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 20 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 21 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 22 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 25 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 26 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 27 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 28 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 29 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 31 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 32 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 33 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 35 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 36 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 37 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 38 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 40 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 41 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 42 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 44 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 45 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 46 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 48 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 50 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 51 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 53 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 54 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 56 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 57 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 58 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 59 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 61 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 63 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 64 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 65 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 66 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 68 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 70 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 71 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 72 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 73 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 75 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 77 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 79 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 81 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 83 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 86 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 88 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 90 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 91 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 92 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 93 due to infeasibility (s->i->e exceeds Tmax).
# Eliminating node 95 due to infeasibility (s->i->e exceeds Tmax).
# Node elimination procedure completed.
# Constructing initial solution using the nearest neighbor algorithm...
# Path 1: Added node 96 (Score: 24.0, Distance: 2.07)
# Path 2: Added node 23 (Score: 21.0, Distance: 2.44)
# Path 1: Added node 7 (Score: 26.0, Distance: 5.08)
# Path 2: Added node 14 (Score: 27.0, Distance: 4.05)
# Path 1: Added node 84 (Score: 24.0, Distance: 7.36)
# Path 2: Added node 67 (Score: 17.0, Distance: 2.85)
# Path 1: Added node 87 (Score: 11.0, Distance: 2.89)
# Path 2: Added node 9 (Score: 16.0, Distance: 1.46)
# Path 1: Added node 43 (Score: 1.0, Distance: 3.67)
# Path 2: Added node 52 (Score: 17.0, Distance: 7.23)
# No further nodes can be added without exceeding Tmax.
# Initial solution constructed with time budget consideration.
# Initializing scores for strategies and operators...
#
# --- Segment 1 ---
#
# Iteration 1 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy lrfi...
# Random number d: 0.6922873986946383
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# New best solution found. Generating and solving SROP...
# Generating and solving SROP...
# s_best updated.
# Temperature updated to 94.9905.
#
# Iteration 2 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.27451671385556087
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# New best solution found. Generating and solving SROP...
# Generating and solving SROP...
# s_best updated.
# Temperature updated to 94.98100095.
#
# Iteration 3 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.9168733490226226
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 1.
# Temperature updated to 94.971502849905.
#
# Iteration 4 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.38433948817690367
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 2.
# Temperature updated to 94.96200569962001.
#
# Iteration 5 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_position with strategy lrfi...
# Random number d: 0.2735832980828762
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 3.
# Temperature updated to 94.95250949905005.
#
# Iteration 6 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.9063185049296149
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 4.
# Temperature updated to 94.94301424810014.
#
# Iteration 7 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.5698100009154372
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 5.
# Temperature updated to 94.93351994667533.
#
# Iteration 8 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.8172915056306319
# Solution not accepted. Iteration best incremented to 6.
# Temperature updated to 94.92402659468067.
#
# Iteration 9 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.9333421680688566
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# New best solution found. Generating and solving SROP...
# Generating and solving SROP...
# s_best updated.
# Temperature updated to 94.91453419202121.
#
# Iteration 10 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy random...
# Random number d: 0.07334532890226753
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 1.
# Temperature updated to 94.905042738602.
#
# Iteration 11 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.8763189501421342
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 2.
# Temperature updated to 94.89555223432815.
#
# Iteration 12 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.79804434147267
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 3.
# Temperature updated to 94.88606267910473.
#
# Iteration 13 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.9093705298420154
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 4.
# Temperature updated to 94.87657407283682.
#
# Iteration 14 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.5012182135017553
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 5.
# Temperature updated to 94.86708641542954.
#
# Iteration 15 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.8303712030679978
# Solution not accepted. Iteration best incremented to 6.
# Temperature updated to 94.857599706788.
#
# Iteration 16 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.25904119780085577
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 7.
# Temperature updated to 94.84811394681732.
#
# Iteration 17 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.8783116820543757
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 8.
# Temperature updated to 94.83862913542264.
#
# Iteration 18 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.8302325542286105
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 9.
# Temperature updated to 94.8291452725091.
#
# Iteration 19 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using last_available with strategy random...
# Random number d: 0.5806101432924413
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 10.
# Temperature updated to 94.81966235798184.
#
# Iteration 20 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using random_available with strategy random...
# Random number d: 0.1896439023840064
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 11.
# Temperature updated to 94.81018039174604.
#
# Iteration 21 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.9704432527566548
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 12.
# Temperature updated to 94.80069937370688.
#
# Iteration 22 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.5367499029105447
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 13.
# Temperature updated to 94.79121930376951.
#
# Iteration 23 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.8770066165448845
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 14.
# Temperature updated to 94.78174018183913.
#
# Iteration 24 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.8087996001841232
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 15.
# Temperature updated to 94.77226200782094.
#
# Iteration 25 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy lrfi...
# Random number d: 0.5121217746837468
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 16.
# Temperature updated to 94.76278478162016.
#
# Iteration 26 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.6168878238734669
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 17.
# Temperature updated to 94.753308503142.
#
# Iteration 27 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using last_available with strategy random...
# Random number d: 0.3886320753495901
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 18.
# Temperature updated to 94.74383317229169.
#
# Iteration 28 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy lrfi...
# Random number d: 0.7785786829064867
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 19.
# Temperature updated to 94.73435878897446.
#
# Iteration 29 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.15792124350836734
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# New best solution found. Generating and solving SROP...
# Generating and solving SROP...
# s_best updated.
# Temperature updated to 94.72488535309556.
#
# Iteration 30 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.14215023271748495
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# New best solution found. Generating and solving SROP...
# Generating and solving SROP...
# s_best updated.
# Temperature updated to 94.71541286456025.
#
# Iteration 31 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.495510121571725
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# New best solution found. Generating and solving SROP...
# Generating and solving SROP...
# s_best updated.
# Temperature updated to 94.70594132327379.
#
# Iteration 32 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.08798352961488198
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 1.
# Temperature updated to 94.69647072914147.
#
# Iteration 33 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.5420084043343528
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 2.
# Temperature updated to 94.68700108206855.
#
# Iteration 34 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.4205753227686402
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 3.
# Temperature updated to 94.67753238196035.
#
# Iteration 35 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using last_available with strategy dynamic_profit_per_time...
# Random number d: 0.6434068154644363
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 4.
# Temperature updated to 94.66806462872215.
#
# Iteration 36 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.6985357999238576
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 5.
# Temperature updated to 94.65859782225928.
#
# Iteration 37 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.8005724917810241
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 6.
# Temperature updated to 94.64913196247706.
#
# Iteration 38 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy lrfi...
# Random number d: 0.8757372155802947
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 7.
# Temperature updated to 94.63966704928082.
#
# Iteration 39 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using last_available with strategy random...
# Random number d: 0.11486885434147442
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 8.
# Temperature updated to 94.63020308257589.
#
# Iteration 40 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.0717478677357577
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 9.
# Temperature updated to 94.62074006226763.
#
# Iteration 41 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using random_available with strategy random...
# Random number d: 0.15852559589228088
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 10.
# Temperature updated to 94.6112779882614.
#
# Iteration 42 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using random_available with strategy random...
# Random number d: 0.7109010907698474
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 11.
# Temperature updated to 94.60181686046258.
#
# Iteration 43 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.4895652322100812
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 12.
# Temperature updated to 94.59235667877653.
#
# Iteration 44 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using last_available with strategy lrfi...
# Random number d: 0.1264720682018904
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 13.
# Temperature updated to 94.58289744310865.
#
# Iteration 45 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_overall_position with strategy dynamic_profit_per_time...
# Random number d: 0.14964988193132178
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 14.
# Temperature updated to 94.57343915336433.
#
# Iteration 46 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.4184853077931183
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 15.
# Temperature updated to 94.563981809449.
#
# Iteration 47 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.605019998970855
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 16.
# Temperature updated to 94.55452541126806.
#
# Iteration 48 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.27352847617343523
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 17.
# Temperature updated to 94.54506995872693.
#
# Iteration 49 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.6805719849689078
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 18.
# Temperature updated to 94.53561545173106.
#
# Iteration 50 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy random...
# Random number d: 0.0009898076265170141
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 19.
# Temperature updated to 94.52616189018589.
#
# Iteration 51 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.800020303897779
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 20.
# Temperature updated to 94.51670927399687.
#
# Iteration 52 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.36541751293755453
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 21.
# Temperature updated to 94.50725760306946.
#
# Iteration 53 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.17369270002369552
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 22.
# Temperature updated to 94.49780687730916.
#
# Iteration 54 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.7664728774717995
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 23.
# Temperature updated to 94.48835709662143.
#
# Iteration 55 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.13428314818642517
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 24.
# Temperature updated to 94.47890826091177.
#
# Iteration 56 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.2550860716050207
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 25.
# Temperature updated to 94.46946037008567.
#
# Iteration 57 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.8132037717506805
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 26.
# Temperature updated to 94.46001342404867.
#
# Iteration 58 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy dynamic_profit_per_time...
# Random number d: 0.8469844311631239
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 27.
# Temperature updated to 94.45056742270627.
#
# Iteration 59 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.7985528207763757
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 28.
# Temperature updated to 94.441122365964.
#
# Iteration 60 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using random_available with strategy random...
# Random number d: 0.11498828952448226
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 29.
# Temperature updated to 94.43167825372741.
#
# Iteration 61 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using last_available with strategy dynamic_profit_per_time...
# Random number d: 0.5856868536945777
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 30.
# Temperature updated to 94.42223508590205.
#
# Iteration 62 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.14940497595322144
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 31.
# Temperature updated to 94.41279286239346.
#
# Iteration 63 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.11892068076521711
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 32.
# Temperature updated to 94.40335158310722.
#
# Iteration 64 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.9011680775491472
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 33.
# Temperature updated to 94.3939112479489.
#
# Iteration 65 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy dynamic_profit_per_time...
# Random number d: 0.25101206116419295
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 34.
# Temperature updated to 94.3844718568241.
#
# Iteration 66 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_overall_position with strategy dynamic_profit_per_time...
# Random number d: 0.19714838027849002
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 35.
# Temperature updated to 94.37503340963842.
#
# Iteration 67 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using last_available with strategy dynamic_profit_per_time...
# Random number d: 0.22333582990115097
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 36.
# Temperature updated to 94.36559590629746.
#
# Iteration 68 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.7266324989569544
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 37.
# Temperature updated to 94.35615934670683.
#
# Iteration 69 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.6306259106881347
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 38.
# Temperature updated to 94.34672373077217.
#
# Iteration 70 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.13454264456881593
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 39.
# Temperature updated to 94.3372890583991.
#
# Iteration 71 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.06303782570001781
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 40.
# Temperature updated to 94.32785532949326.
#
# Iteration 72 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.4087608822341968
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 41.
# Temperature updated to 94.31842254396031.
#
# Iteration 73 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy dynamic_profit_per_time...
# Random number d: 0.7469580107690151
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 42.
# Temperature updated to 94.30899070170591.
#
# Iteration 74 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy random...
# Random number d: 0.37711683415107555
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 43.
# Temperature updated to 94.29955980263574.
#
# Iteration 75 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.45156014175455006
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 44.
# Temperature updated to 94.29012984665547.
#
# Iteration 76 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.16573661801193396
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 45.
# Temperature updated to 94.2807008336708.
#
# Iteration 77 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.9419714017841672
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 46.
# Temperature updated to 94.27127276358745.
#
# Iteration 78 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.2341347082200801
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 47.
# Temperature updated to 94.2618456363111.
#
# Iteration 79 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using last_available with strategy dynamic_profit_per_time...
# Random number d: 0.5704430254269441
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 48.
# Temperature updated to 94.25241945174746.
#
# Iteration 80 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.22357742905915567
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 49.
# Temperature updated to 94.24299420980228.
#
# Iteration 81 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_overall_position with strategy highest_profit...
# Random number d: 0.6260178914866514
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 50.
# Temperature updated to 94.23356991038129.
#
# Iteration 82 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.06911867678747063
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 51.
# Temperature updated to 94.22414655339026.
#
# Iteration 83 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.8133346589383127
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 52.
# Temperature updated to 94.21472413873492.
#
# Iteration 84 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.7238580411916637
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 53.
# Temperature updated to 94.20530266632105.
#
# Iteration 85 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.7918939860139453
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 54.
# Temperature updated to 94.19588213605441.
#
# Iteration 86 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.48671605862033007
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 55.
# Temperature updated to 94.1864625478408.
#
# Iteration 87 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.012805524448050498
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 56.
# Temperature updated to 94.17704390158602.
#
# Iteration 88 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.32204313339949187
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 57.
# Temperature updated to 94.16762619719586.
#
# Iteration 89 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.27179142319047456
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 58.
# Temperature updated to 94.15820943457614.
#
# Iteration 90 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.7453663001116521
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 59.
# Temperature updated to 94.14879361363268.
#
# Iteration 91 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.3977290530504938
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 60.
# Temperature updated to 94.13937873427132.
#
# Iteration 92 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.4482901468775514
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 61.
# Temperature updated to 94.12996479639789.
#
# Iteration 93 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using random_available with strategy random...
# Random number d: 0.16912791296254448
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 62.
# Temperature updated to 94.12055179991825.
#
# Iteration 94 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.2671257495952406
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 63.
# Temperature updated to 94.11113974473825.
#
# Iteration 95 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.26568571467648716
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 64.
# Temperature updated to 94.10172863076377.
#
# Iteration 96 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy highest_profit...
# Random number d: 0.16241205763396793
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 65.
# Temperature updated to 94.0923184579007.
#
# Iteration 97 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.12609142896777847
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 66.
# Temperature updated to 94.08290922605491.
#
# Iteration 98 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy dynamic_profit_per_time...
# Random number d: 0.6739619539818897
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 67.
# Temperature updated to 94.0735009351323.
#
# Iteration 99 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.13124675337271696
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 68.
# Temperature updated to 94.06409358503879.
#
# Iteration 100 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# ...
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.09828085103858109
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 409.
# Temperature updated to 86.2691509512903.
#
# Iteration 965 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.18084112295828203
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 410.
# Temperature updated to 86.26052403619518.
#
# Iteration 966 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.3904646345946031
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 411.
# Temperature updated to 86.25189798379157.
#
# Iteration 967 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.6320294696990275
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 412.
# Temperature updated to 86.24327279399319.
#
# Iteration 968 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.48710750708828343
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 413.
# Temperature updated to 86.2346484667138.
#
# Iteration 969 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.22115811902703908
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 414.
# Temperature updated to 86.22602500186713.
#
# Iteration 970 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.23505088254455297
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 415.
# Temperature updated to 86.21740239936695.
#
# Iteration 971 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.09386603169079544
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 416.
# Temperature updated to 86.20878065912702.
#
# Iteration 972 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.8536428195212046
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 417.
# Temperature updated to 86.2001597810611.
#
# Iteration 973 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.8798082788366872
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 418.
# Temperature updated to 86.191539765083.
#
# Iteration 974 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.8198392612190142
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 419.
# Temperature updated to 86.18292061110648.
#
# Iteration 975 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.736782978803417
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 420.
# Temperature updated to 86.17430231904537.
#
# Iteration 976 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.7797787836433635
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 421.
# Temperature updated to 86.16568488881346.
#
# Iteration 977 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using best_position with strategy random...
# Random number d: 0.9256453841822297
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 422.
# Temperature updated to 86.15706832032458.
#
# Iteration 978 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_overall_position with strategy dynamic_profit_per_time...
# Random number d: 0.9730556656101633
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 423.
# Temperature updated to 86.14845261349255.
#
# Iteration 979 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using random_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.4427294188505655
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 424.
# Temperature updated to 86.1398377682312.
#
# Iteration 980 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using first_available with strategy random...
# Random number d: 0.5791441413262899
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 425.
# Temperature updated to 86.13122378445438.
#
# Iteration 981 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.4002646789445139
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 426.
# Temperature updated to 86.12261066207593.
#
# Iteration 982 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.11590911306260188
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 427.
# Temperature updated to 86.11399840100972.
#
# Iteration 983 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy lrfi...
# Random number d: 0.9344492327594618
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 428.
# Temperature updated to 86.10538700116962.
#
# Iteration 984 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using best_position with strategy lrfi...
# Random number d: 0.9269963881776313
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 429.
# Temperature updated to 86.0967764624695.
#
# Iteration 985 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using best_overall_position with strategy random...
# Random number d: 0.11428359797600807
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 430.
# Temperature updated to 86.08816678482326.
#
# Iteration 986 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.3666871965457599
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 431.
# Temperature updated to 86.07955796814478.
#
# Iteration 987 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.4124287520226584
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 432.
# Temperature updated to 86.07095001234796.
#
# Iteration 988 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.2783713930518442
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 433.
# Temperature updated to 86.06234291734673.
#
# Iteration 989 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using random_available with strategy dynamic_profit_per_time...
# Random number d: 0.0497345150049755
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 434.
# Temperature updated to 86.05373668305499.
#
# Iteration 990 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.6817502799184275
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 435.
# Temperature updated to 86.04513130938669.
#
# Iteration 991 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using random_available with strategy lrfi...
# Random number d: 0.5340006366391159
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 436.
# Temperature updated to 86.03652679625576.
#
# Iteration 992 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using last_available with strategy highest_profit...
# Random number d: 0.609651867443467
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 437.
# Temperature updated to 86.02792314357613.
#
# Iteration 993 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using best_overall_position with strategy lrfi...
# Random number d: 0.8566010373398657
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 438.
# Temperature updated to 86.01932035126177.
#
# Iteration 994 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using best_position with strategy dynamic_profit_per_time...
# Random number d: 0.5344178168830942
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 439.
# Temperature updated to 86.01071841922665.
#
# Iteration 995 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using first_available with strategy highest_profit...
# Random number d: 0.7883851044137661
# Solution accepted based on acceptance criteria.
# Applying local search procedures...
# Applied local search.
# Iteration best incremented to 440.
# Temperature updated to 86.00211734738473.
#
# Iteration 996 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using lowest_profit_removal...
# Inserting nodes using best_position with strategy highest_profit...
# Random number d: 0.053377040834307055
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 441.
# Temperature updated to 85.99351713565.
#
# Iteration 997 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using route_removal...
# Inserting nodes using last_available with strategy random...
# Random number d: 0.2540998501406073
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 442.
# Temperature updated to 85.98491778393642.
#
# Iteration 998 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using first_available with strategy random...
# Random number d: 0.2145480627465065
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 443.
# Temperature updated to 85.97631929215804.
#
# Iteration 999 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using largest_saving_removal...
# Inserting nodes using first_available with strategy lrfi...
# Random number d: 0.2585423186060385
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 444.
# Temperature updated to 85.96772166022882.
#
# Iteration 1000 within Segment 1
# Number of nodes to remove: 1
# Selecting node selection strategy...
# Selecting removal and insertion operators...
# Removing 1 nodes using sequence_removal...
# Inserting nodes using last_available with strategy random...
# Random number d: 0.6828095008662317
# Solution accepted based on acceptance criteria.
# Iteration best incremented to 445.
# Temperature updated to 85.9591248880628.
# Updating scores of the ALNS operators and insertion strategies...
# Score update completed.
# Segment 1 completed.
#
# Generating and solving final SPP...
# Generating and solving SPP...
# Final solution obtained.
# Best Solution: [[0, 96, 23, 7, 94, 84, 87, 43, 34], [0, 14, 9, 67, 69, 80, 10, 34]]
# Total Prize Collected: 230.0

# %%
n,p,t,nodes = read_top_instance(file_path)

# %%
n,p,t,nodes
# Out:
# (100,
#  2,
#  25.0,
#  [{'id': 0, 'x': 18.19, 'y': 6.32, 'score': 0.0},
#   {'id': 1, 'x': 15.52, 'y': 28.03, 'score': 7.0},
#   {'id': 2, 'x': 9.0, 'y': 28.01, 'score': 5.0},
#   {'id': 3, 'x': 16.93, 'y': 2.09, 'score': 24.0},
#   {'id': 4, 'x': 8.64, 'y': 19.85, 'score': 3.0},
#   {'id': 5, 'x': 18.43, 'y': 29.93, 'score': 23.0},
#   {'id': 6, 'x': 3.94, 'y': 10.77, 'score': 3.0},
#   {'id': 7, 'x': 14.78, 'y': 7.61, 'score': 26.0},
#   {'id': 8, 'x': 2.41, 'y': 25.06, 'score': 24.0},
#   {'id': 9, 'x': 18.41, 'y': 11.88, 'score': 16.0},
#   {'id': 10, 'x': 14.91, 'y': 17.24, 'score': 21.0},
#   {'id': 11, 'x': 7.14, 'y': 0.48, 'score': 6.0},
#   {'id': 12, 'x': 13.44, 'y': 24.76, 'score': 17.0},
#   {'id': 13, 'x': 17.54, 'y': 29.43, 'score': 27.0},
#   {'id': 14, 'x': 16.71, 'y': 9.5, 'score': 27.0},
#   {'id': 15, 'x': 12.38, 'y': 26.66, 'score': 1.0},
#   {'id': 16, 'x': 25.69, 'y': 6.34, 'score': 6.0},
#   {'id': 17, 'x': 11.62, 'y': 24.0, 'score': 27.0},
#   {'id': 18, 'x': 10.24, 'y': 3.02, 'score': 23.0},
#   {'id': 19, 'x': 3.54, 'y': 26.16, 'score': 18.0},
#   {'id': 20, 'x': 17.86, 'y': 19.36, 'score': 13.0},
#   {'id': 21, 'x': 3.77, 'y': 7.84, 'score': 1.0},
#   {'id': 22, 'x': 14.2, 'y': 19.64, 'score': 13.0},
#   {'id': 23, 'x': 15.88, 'y': 5.54, 'score': 21.0},
#   {'id': 24, 'x': 1.32, 'y': 19.32, 'score': 23.0},
#   {'id': 25, 'x': 20.5, 'y': 25.33, 'score': 16.0},
#   {'id': 26, 'x': 16.76, 'y': 19.84, 'score': 8.0},
#   {'id': 27, 'x': 27.5, 'y': 17.66, 'score': 24.0},
#   {'id': 28, 'x': 19.41, 'y': 20.67, 'score': 15.0},
#   {'id': 29, 'x': 20.49, 'y': 14.03, 'score': 24.0},
#   {'id': 30, 'x': 20.9, 'y': 7.67, 'score': 8.0},
#   {'id': 31, 'x': 2.75, 'y': 25.4, 'score': 5.0},
#   {'id': 32, 'x': 16.1, 'y': 19.74, 'score': 3.0},
#   {'id': 33, 'x': 0.43, 'y': 1.12, 'score': 9.0},
#   {'id': 34, 'x': 13.57, 'y': 9.41, 'score': 11.0},
#   {'id': 35, 'x': 0.3, 'y': 9.16, 'score': 7.0},
#   {'id': 36, 'x': 0.45, 'y': 23.35, 'score': 10.0},
#   {'id': 37, 'x': 22.69, 'y': 23.13, 'score': 13.0},
#   {'id': 38, 'x': 19.12, 'y': 20.2, 'score': 13.0},
#   {'id': 39, 'x': 7.0, 'y': 21.44, 'score': 8.0},
#   {'id': 40, 'x': 28.88, 'y': 0.86, 'score': 24.0},
#   {'id': 41, 'x': 19.6, 'y': 2.11, 'score': 14.0},
#   {'id': 42, 'x': 22.78, 'y': 15.42, 'score': 27.0},
#   {'id': 43, 'x': 13.51, 'y': 8.05, 'score': 1.0},
#   {'id': 44, 'x': 0.51, 'y': 11.06, 'score': 5.0},
#   {'id': 45, 'x': 4.31, 'y': 23.12, 'score': 20.0},
#   {'id': 46, 'x': 19.68, 'y': 25.62, 'score': 5.0},
#   {'id': 47, 'x': 16.32, 'y': 3.73, 'score': 3.0},
#   {'id': 48, 'x': 7.14, 'y': 25.9, 'score': 13.0},
#   {'id': 49, 'x': 1.04, 'y': 13.47, 'score': 6.0},
#   {'id': 50, 'x': 17.46, 'y': 2.56, 'score': 28.0},
#   {'id': 51, 'x': 23.49, 'y': 17.75, 'score': 5.0},
#   {'id': 52, 'x': 11.96, 'y': 15.15, 'score': 17.0},
#   {'id': 53, 'x': 22.85, 'y': 14.85, 'score': 2.0},
#   {'id': 54, 'x': 28.47, 'y': 6.08, 'score': 23.0},
#   {'id': 55, 'x': 6.52, 'y': 19.42, 'score': 17.0},
#   {'id': 56, 'x': 26.85, 'y': 25.82, 'score': 6.0},
#   {'id': 57, 'x': 21.48, 'y': 10.3, 'score': 21.0},
#   {'id': 58, 'x': 29.08, 'y': 2.62, 'score': 18.0},
#   {'id': 59, 'x': 22.54, 'y': 18.26, 'score': 14.0},
#   {'id': 60, 'x': 4.46, 'y': 7.85, 'score': 7.0},
#   {'id': 61, 'x': 21.61, 'y': 23.16, 'score': 4.0},
#   {'id': 62, 'x': 6.82, 'y': 21.1, 'score': 13.0},
#   {'id': 63, 'x': 6.48, 'y': 2.46, 'score': 25.0},
#   {'id': 64, 'x': 26.7, 'y': 3.44, 'score': 27.0},
#   {'id': 65, 'x': 7.03, 'y': 28.12, 'score': 1.0},
#   {'id': 66, 'x': 20.3, 'y': 3.86, 'score': 2.0},
#   {'id': 67, 'x': 17.02, 'y': 12.33, 'score': 17.0},
#   {'id': 68, 'x': 0.2, 'y': 24.8, 'score': 3.0},
#   {'id': 69, 'x': 13.97, 'y': 18.49, 'score': 4.0},
#   {'id': 70, 'x': 1.88, 'y': 3.33, 'score': 13.0},
#   {'id': 71, 'x': 14.25, 'y': 23.83, 'score': 1.0},
#   {'id': 72, 'x': 27.22, 'y': 11.98, 'score': 16.0},
#   {'id': 73, 'x': 22.05, 'y': 7.74, 'score': 10.0},
#   {'id': 74, 'x': 3.08, 'y': 21.03, 'score': 13.0},
#   {'id': 75, 'x': 12.66, 'y': 26.02, 'score': 3.0},
#   {'id': 76, 'x': 3.69, 'y': 14.33, 'score': 21.0},
#   {'id': 77, 'x': 26.93, 'y': 13.06, 'score': 24.0},
#   {'id': 78, 'x': 1.57, 'y': 19.84, 'score': 19.0},
#   {'id': 79, 'x': 19.01, 'y': 14.36, 'score': 13.0},
#   {'id': 80, 'x': 14.24, 'y': 18.8, 'score': 19.0},
#   {'id': 81, 'x': 20.49, 'y': 13.59, 'score': 8.0},
#   {'id': 82, 'x': 3.3, 'y': 17.86, 'score': 1.0},
#   {'id': 83, 'x': 28.72, 'y': 20.92, 'score': 29.0},
#   {'id': 84, 'x': 7.49, 'y': 6.59, 'score': 24.0},
#   {'id': 85, 'x': 12.19, 'y': 16.11, 'score': 1.0},
#   {'id': 86, 'x': 17.52, 'y': 0.97, 'score': 10.0},
#   {'id': 87, 'x': 10.35, 'y': 6.18, 'score': 11.0},
#   {'id': 88, 'x': 13.61, 'y': 21.12, 'score': 17.0},
#   {'id': 89, 'x': 0.26, 'y': 14.37, 'score': 13.0},
#   {'id': 90, 'x': 12.58, 'y': 26.64, 'score': 16.0},
#   {'id': 91, 'x': 21.57, 'y': 24.07, 'score': 2.0},
#   {'id': 92, 'x': 14.5, 'y': 0.3, 'score': 22.0},
#   {'id': 93, 'x': 25.6, 'y': 22.91, 'score': 2.0},
#   {'id': 94, 'x': 10.92, 'y': 4.13, 'score': 8.0},
#   {'id': 95, 'x': 26.65, 'y': 20.04, 'score': 28.0},
#   {'id': 96, 'x': 18.63, 'y': 4.3, 'score': 24.0},
#   {'id': 97, 'x': 7.29, 'y': 16.28, 'score': 12.0},
#   {'id': 98, 'x': 4.34, 'y': 9.51, 'score': 5.0},
#   {'id': 99, 'x': 2.38, 'y': 18.26, 'score': 0.0}])

# %%
halns.problem.node_dict
# Out:
# {0: {'id': 0, 'x': 18.19, 'y': 6.32, 'score': 0.0},
#  4: {'id': 4, 'x': 8.64, 'y': 19.85, 'score': 3.0},
#  6: {'id': 6, 'x': 3.94, 'y': 10.77, 'score': 3.0},
#  7: {'id': 7, 'x': 14.78, 'y': 7.61, 'score': 26.0},
#  9: {'id': 9, 'x': 18.41, 'y': 11.88, 'score': 16.0},
#  10: {'id': 10, 'x': 14.91, 'y': 17.24, 'score': 21.0},
#  14: {'id': 14, 'x': 16.71, 'y': 9.5, 'score': 27.0},
#  23: {'id': 23, 'x': 15.88, 'y': 5.54, 'score': 21.0},
#  24: {'id': 24, 'x': 1.32, 'y': 19.32, 'score': 23.0},
#  30: {'id': 30, 'x': 20.9, 'y': 7.67, 'score': 8.0},
#  34: {'id': 34, 'x': 13.57, 'y': 9.41, 'score': 11.0},
#  39: {'id': 39, 'x': 7.0, 'y': 21.44, 'score': 8.0},
#  43: {'id': 43, 'x': 13.51, 'y': 8.05, 'score': 1.0},
#  47: {'id': 47, 'x': 16.32, 'y': 3.73, 'score': 3.0},
#  49: {'id': 49, 'x': 1.04, 'y': 13.47, 'score': 6.0},
#  52: {'id': 52, 'x': 11.96, 'y': 15.15, 'score': 17.0},
#  55: {'id': 55, 'x': 6.52, 'y': 19.42, 'score': 17.0},
#  60: {'id': 60, 'x': 4.46, 'y': 7.85, 'score': 7.0},
#  62: {'id': 62, 'x': 6.82, 'y': 21.1, 'score': 13.0},
#  67: {'id': 67, 'x': 17.02, 'y': 12.33, 'score': 17.0},
#  69: {'id': 69, 'x': 13.97, 'y': 18.49, 'score': 4.0},
#  74: {'id': 74, 'x': 3.08, 'y': 21.03, 'score': 13.0},
#  76: {'id': 76, 'x': 3.69, 'y': 14.33, 'score': 21.0},
#  78: {'id': 78, 'x': 1.57, 'y': 19.84, 'score': 19.0},
#  80: {'id': 80, 'x': 14.24, 'y': 18.8, 'score': 19.0},
#  82: {'id': 82, 'x': 3.3, 'y': 17.86, 'score': 1.0},
#  84: {'id': 84, 'x': 7.49, 'y': 6.59, 'score': 24.0},
#  85: {'id': 85, 'x': 12.19, 'y': 16.11, 'score': 1.0},
#  87: {'id': 87, 'x': 10.35, 'y': 6.18, 'score': 11.0},
#  89: {'id': 89, 'x': 0.26, 'y': 14.37, 'score': 13.0},
#  94: {'id': 94, 'x': 10.92, 'y': 4.13, 'score': 8.0},
#  96: {'id': 96, 'x': 18.63, 'y': 4.3, 'score': 24.0},
#  97: {'id': 97, 'x': 7.29, 'y': 16.28, 'score': 12.0},
#  98: {'id': 98, 'x': 4.34, 'y': 9.51, 'score': 5.0},
#  99: {'id': 99, 'x': 2.38, 'y': 18.26, 'score': 0.0}}

# %%
halns.problem.N,halns.problem.P
# Out:
# (35, 2)

# %%
visited = set()
for route in best_solution:
    for nid in route:
        visited.add(nid)

print("Visited Nodes:", visited)

total_score = 0.0
for nid in visited:
    score = halns.problem.node_dict[nid]['score'] if nid in halns.problem.node_dict else None
    print(f"Node {nid}: Score={score}")
    if score is not None:
        total_score += score
print("Total Prize Collected:", total_score)
# Out:
# Visited Nodes: {0, 96, 34, 67, 69, 7, 10, 43, 14, 80, 52, 85, 84, 23, 87, 94}
# Node 0: Score=0.0
# Node 96: Score=24.0
# Node 34: Score=11.0
# Node 67: Score=17.0
# Node 69: Score=4.0
# Node 7: Score=26.0
# Node 10: Score=21.0
# Node 43: Score=1.0
# Node 14: Score=27.0
# Node 80: Score=19.0
# Node 52: Score=17.0
# Node 85: Score=1.0
# Node 84: Score=24.0
# Node 23: Score=21.0
# Node 87: Score=11.0
# Node 94: Score=8.0
# Total Prize Collected: 232.0
